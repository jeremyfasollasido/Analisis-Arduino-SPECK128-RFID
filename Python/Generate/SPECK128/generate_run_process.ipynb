# %%
import os

# Folder output utama
code_folders = ["speck128rfida", "speck128rfidb", "speck128rfidc", "speck128rfidd", "speck128rfide"]

# Buat folder utama jika belum ada
for folder in code_folders:
    os.makedirs(folder, exist_ok=True)

def generate_code_with_decrementing_plaintext(file_path, id_values):
    # Template kode Arduino
    code_template = f"""
#include <SPI.h>
#include <MFRC522.h>
#include <Wire.h>
#include <Adafruit_INA219.h>
#include <Crypto.h>
#include <Speck.h>
#include <string.h>
#include <MemoryFree.h>
#include <LiquidCrystal_I2C.h>

#define SS_PIN 10
#define RST_PIN 9

MFRC522 rfid(SS_PIN, RST_PIN);
Adafruit_INA219 ina219;
LiquidCrystal_I2C lcd(0x27, 16, 2);

Speck speck128;
byte buffer[16];

byte ciphertext[{id_values}];
byte decryptedtext[{id_values}];
unsigned long encryptionTime;
unsigned long decryptionTime;

float encryptionVoltage;
float encryptionCurrent;
float decryptionVoltage;
float decryptionCurrent;

const byte keySpeck128[16] = {{ 0x0f, 0x0e, 0x0d, 0x0c, 0x0b, 0x0a, 0x09, 0x08,
                              0x07, 0x06, 0x05, 0x04, 0x03, 0x02, 0x01, 0x00 }};

void encryptAndPrint(BlockCipher *cipher, const byte *key, size_t keySize, byte *plaintext, size_t plaintextSize) {{
  unsigned long startTime = micros();
  cipher->setKey(key, keySize);

  for (size_t i = 0; i < plaintextSize; i += 16) {{
    cipher->encryptBlock(buffer, &plaintext[i]);
    memcpy(&ciphertext[i], buffer, 16);
  }}

  unsigned long endTime = micros();
  encryptionVoltage = ina219.getBusVoltage_V();
  encryptionCurrent = ina219.getCurrent_mA();
  encryptionTime = endTime - startTime;

  // Output encrypted data (ciphertext)
  Serial.print(F("Ciphertext: "));
  for (size_t i = 0; i < plaintextSize; i++) {{
    if (ciphertext[i] < 0x10) Serial.print("0");
    Serial.print(ciphertext[i], HEX);
    Serial.print(" ");
  }}
  Serial.println();
  Serial.print(F("Encryption Completed in "));
  Serial.print(encryptionTime);
  Serial.println(F(" us"));
}}

void decryptAndPrint(BlockCipher *cipher, const byte *key, size_t keySize, byte *ciphertext, size_t ciphertextSize) {{
    unsigned long startdecTime = micros();
    cipher->setKey(key, keySize);

    for (size_t i = 0; i < ciphertextSize; i += 16) {{
        cipher->decryptBlock(buffer, &ciphertext[i]);
        memcpy(&decryptedtext[i], buffer, 16);
    }}

    unsigned long enddecTime = micros();
    decryptionVoltage = ina219.getBusVoltage_V();
    decryptionCurrent = ina219.getCurrent_mA();
    decryptionTime = enddecTime - startdecTime;

    // Output decrypted data
    Serial.print(F("Decrypted Text: "));
    for (size_t i = 0; i < ciphertextSize; i++) {{
        if (decryptedtext[i] < 0x10) Serial.print("0");
        Serial.print(decryptedtext[i], HEX);
        Serial.print(" ");
    }}
    Serial.println();
    Serial.print(F("Decryption Completed in "));
    Serial.print(decryptionTime);
    Serial.println(F(" us"));
}}

void displayData() {{
    float encryptionPower = encryptionVoltage * (encryptionCurrent / 1000);
    float decryptionPower = decryptionVoltage * (decryptionCurrent / 1000);
    int memoryUsage = 2048 - freeMemory();

    Serial.print(F("Memory Usage = "));
    Serial.print(memoryUsage);
    Serial.println(F(" B"));
    Serial.println();

    Serial.print(F("Encryption Voltage: "));
    Serial.print(encryptionVoltage);
    Serial.println(F(" V"));
    Serial.print(F("Encryption Current: "));
    Serial.print(encryptionCurrent);
    Serial.println(F(" mA"));
    Serial.print(F("Encryption Power: "));
    Serial.print(encryptionPower);
    Serial.println(F(" W"));
    Serial.println();
    
    Serial.print(F("Decryption Voltage: "));
    Serial.print(decryptionVoltage);
    Serial.println(F(" V"));
    Serial.print(F("Decryption Current: "));
    Serial.print(decryptionCurrent);
    Serial.println(F(" mA"));
    Serial.print(F("Decryption Power: "));
    Serial.print(decryptionPower);
    Serial.println(F(" W"));

    Serial.println(F("selesai"));
}}

void setup() {{
    Serial.begin(9600);
    SPI.begin();
    rfid.PCD_Init();
    ina219.begin();
    
    lcd.begin(16, 2);
    lcd.backlight();
    lcd.setCursor(0, 0);
    lcd.print("RFID System Ready");
    delay(2000);
    lcd.clear();
}}

void loop() {{
    if (rfid.PICC_IsNewCardPresent() && rfid.PICC_ReadCardSerial()) {{
        byte cardID[{id_values}] = {{0}};
        size_t idLength = rfid.uid.size;

        for (byte i = 0; i < idLength && i < {id_values}; i++) {{
            cardID[i] = rfid.uid.uidByte[i];
        }}

        if (idLength < {id_values}) {{
            memset(&cardID[idLength], 0, {id_values} - idLength);
        }}

        lcd.clear();
        lcd.setCursor(0, 0);
        lcd.print("RFID Detected!");
        lcd.setCursor(0, 1);
        lcd.print("Encrypting...");

        encryptAndPrint(&speck128, keySpeck128, sizeof(keySpeck128), cardID, {id_values});
        decryptAndPrint(&speck128, keySpeck128, sizeof(keySpeck128), ciphertext, {id_values});
        displayData();

        lcd.clear();
        lcd.setCursor(0, 0);
        lcd.print("Encryption Done!");
        delay(2000);
        lcd.clear();
    }}
}}
"""

    with open(file_path, 'w') as file:
        file.write(code_template)

    print(f"Code with {id_values}-byte plaintext has been written to {file_path}")

# Generate folders and codes
for folder in code_folders:
    for i in range(400, 15, -16):
        filename = f"speck128rfid_{i}"
        sketch_folder = os.path.join(folder, filename)
        os.makedirs(sketch_folder, exist_ok=True)  # Membuat folder untuk setiap file

        file_path = os.path.join(sketch_folder, f"{filename}.ino")

        generate_code_with_decrementing_plaintext(file_path, i)
# Out:
# Code with 400-byte plaintext has been written to speck128rfida\speck128rfid_400\speck128rfid_400.ino
# Code with 384-byte plaintext has been written to speck128rfida\speck128rfid_384\speck128rfid_384.ino
# Code with 368-byte plaintext has been written to speck128rfida\speck128rfid_368\speck128rfid_368.ino
# Code with 352-byte plaintext has been written to speck128rfida\speck128rfid_352\speck128rfid_352.ino
# Code with 336-byte plaintext has been written to speck128rfida\speck128rfid_336\speck128rfid_336.ino
# Code with 320-byte plaintext has been written to speck128rfida\speck128rfid_320\speck128rfid_320.ino
# Code with 304-byte plaintext has been written to speck128rfida\speck128rfid_304\speck128rfid_304.ino
# Code with 288-byte plaintext has been written to speck128rfida\speck128rfid_288\speck128rfid_288.ino
# Code with 272-byte plaintext has been written to speck128rfida\speck128rfid_272\speck128rfid_272.ino
# Code with 256-byte plaintext has been written to speck128rfida\speck128rfid_256\speck128rfid_256.ino
# Code with 240-byte plaintext has been written to speck128rfida\speck128rfid_240\speck128rfid_240.ino
# Code with 224-byte plaintext has been written to speck128rfida\speck128rfid_224\speck128rfid_224.ino
# Code with 208-byte plaintext has been written to speck128rfida\speck128rfid_208\speck128rfid_208.ino
# Code with 192-byte plaintext has been written to speck128rfida\speck128rfid_192\speck128rfid_192.ino
# Code with 176-byte plaintext has been written to speck128rfida\speck128rfid_176\speck128rfid_176.ino
# Code with 160-byte plaintext has been written to speck128rfida\speck128rfid_160\speck128rfid_160.ino
# Code with 144-byte plaintext has been written to speck128rfida\speck128rfid_144\speck128rfid_144.ino
# Code with 128-byte plaintext has been written to speck128rfida\speck128rfid_128\speck128rfid_128.ino
# Code with 112-byte plaintext has been written to speck128rfida\speck128rfid_112\speck128rfid_112.ino
# Code with 96-byte plaintext has been written to speck128rfida\speck128rfid_96\speck128rfid_96.ino
# Code with 80-byte plaintext has been written to speck128rfida\speck128rfid_80\speck128rfid_80.ino
# Code with 64-byte plaintext has been written to speck128rfida\speck128rfid_64\speck128rfid_64.ino
# Code with 48-byte plaintext has been written to speck128rfida\speck128rfid_48\speck128rfid_48.ino
# Code with 32-byte plaintext has been written to speck128rfida\speck128rfid_32\speck128rfid_32.ino
# Code with 16-byte plaintext has been written to speck128rfida\speck128rfid_16\speck128rfid_16.ino
# Code with 400-byte plaintext has been written to speck128rfidb\speck128rfid_400\speck128rfid_400.ino
# Code with 384-byte plaintext has been written to speck128rfidb\speck128rfid_384\speck128rfid_384.ino
# Code with 368-byte plaintext has been written to speck128rfidb\speck128rfid_368\speck128rfid_368.ino
# Code with 352-byte plaintext has been written to speck128rfidb\speck128rfid_352\speck128rfid_352.ino
# Code with 336-byte plaintext has been written to speck128rfidb\speck128rfid_336\speck128rfid_336.ino
# Code with 320-byte plaintext has been written to speck128rfidb\speck128rfid_320\speck128rfid_320.ino
# Code with 304-byte plaintext has been written to speck128rfidb\speck128rfid_304\speck128rfid_304.ino
# Code with 288-byte plaintext has been written to speck128rfidb\speck128rfid_288\speck128rfid_288.ino
# Code with 272-byte plaintext has been written to speck128rfidb\speck128rfid_272\speck128rfid_272.ino
# Code with 256-byte plaintext has been written to speck128rfidb\speck128rfid_256\speck128rfid_256.ino
# Code with 240-byte plaintext has been written to speck128rfidb\speck128rfid_240\speck128rfid_240.ino
# Code with 224-byte plaintext has been written to speck128rfidb\speck128rfid_224\speck128rfid_224.ino
# Code with 208-byte plaintext has been written to speck128rfidb\speck128rfid_208\speck128rfid_208.ino
# Code with 192-byte plaintext has been written to speck128rfidb\speck128rfid_192\speck128rfid_192.ino
# Code with 176-byte plaintext has been written to speck128rfidb\speck128rfid_176\speck128rfid_176.ino
# Code with 160-byte plaintext has been written to speck128rfidb\speck128rfid_160\speck128rfid_160.ino
# Code with 144-byte plaintext has been written to speck128rfidb\speck128rfid_144\speck128rfid_144.ino
# Code with 128-byte plaintext has been written to speck128rfidb\speck128rfid_128\speck128rfid_128.ino
# Code with 112-byte plaintext has been written to speck128rfidb\speck128rfid_112\speck128rfid_112.ino
# Code with 96-byte plaintext has been written to speck128rfidb\speck128rfid_96\speck128rfid_96.ino
# Code with 80-byte plaintext has been written to speck128rfidb\speck128rfid_80\speck128rfid_80.ino
# Code with 64-byte plaintext has been written to speck128rfidb\speck128rfid_64\speck128rfid_64.ino
# Code with 48-byte plaintext has been written to speck128rfidb\speck128rfid_48\speck128rfid_48.ino
# Code with 32-byte plaintext has been written to speck128rfidb\speck128rfid_32\speck128rfid_32.ino
# Code with 16-byte plaintext has been written to speck128rfidb\speck128rfid_16\speck128rfid_16.ino
# Code with 400-byte plaintext has been written to speck128rfidc\speck128rfid_400\speck128rfid_400.ino
# Code with 384-byte plaintext has been written to speck128rfidc\speck128rfid_384\speck128rfid_384.ino
# Code with 368-byte plaintext has been written to speck128rfidc\speck128rfid_368\speck128rfid_368.ino
# Code with 352-byte plaintext has been written to speck128rfidc\speck128rfid_352\speck128rfid_352.ino
# Code with 336-byte plaintext has been written to speck128rfidc\speck128rfid_336\speck128rfid_336.ino
# Code with 320-byte plaintext has been written to speck128rfidc\speck128rfid_320\speck128rfid_320.ino
# Code with 304-byte plaintext has been written to speck128rfidc\speck128rfid_304\speck128rfid_304.ino
# Code with 288-byte plaintext has been written to speck128rfidc\speck128rfid_288\speck128rfid_288.ino
# Code with 272-byte plaintext has been written to speck128rfidc\speck128rfid_272\speck128rfid_272.ino
# Code with 256-byte plaintext has been written to speck128rfidc\speck128rfid_256\speck128rfid_256.ino
# Code with 240-byte plaintext has been written to speck128rfidc\speck128rfid_240\speck128rfid_240.ino
# Code with 224-byte plaintext has been written to speck128rfidc\speck128rfid_224\speck128rfid_224.ino
# Code with 208-byte plaintext has been written to speck128rfidc\speck128rfid_208\speck128rfid_208.ino
# Code with 192-byte plaintext has been written to speck128rfidc\speck128rfid_192\speck128rfid_192.ino
# Code with 176-byte plaintext has been written to speck128rfidc\speck128rfid_176\speck128rfid_176.ino
# Code with 160-byte plaintext has been written to speck128rfidc\speck128rfid_160\speck128rfid_160.ino
# Code with 144-byte plaintext has been written to speck128rfidc\speck128rfid_144\speck128rfid_144.ino
# Code with 128-byte plaintext has been written to speck128rfidc\speck128rfid_128\speck128rfid_128.ino
# Code with 112-byte plaintext has been written to speck128rfidc\speck128rfid_112\speck128rfid_112.ino
# Code with 96-byte plaintext has been written to speck128rfidc\speck128rfid_96\speck128rfid_96.ino
# Code with 80-byte plaintext has been written to speck128rfidc\speck128rfid_80\speck128rfid_80.ino
# Code with 64-byte plaintext has been written to speck128rfidc\speck128rfid_64\speck128rfid_64.ino
# Code with 48-byte plaintext has been written to speck128rfidc\speck128rfid_48\speck128rfid_48.ino
# Code with 32-byte plaintext has been written to speck128rfidc\speck128rfid_32\speck128rfid_32.ino
# Code with 16-byte plaintext has been written to speck128rfidc\speck128rfid_16\speck128rfid_16.ino
# Code with 400-byte plaintext has been written to speck128rfidd\speck128rfid_400\speck128rfid_400.ino
# Code with 384-byte plaintext has been written to speck128rfidd\speck128rfid_384\speck128rfid_384.ino
# Code with 368-byte plaintext has been written to speck128rfidd\speck128rfid_368\speck128rfid_368.ino
# Code with 352-byte plaintext has been written to speck128rfidd\speck128rfid_352\speck128rfid_352.ino
# Code with 336-byte plaintext has been written to speck128rfidd\speck128rfid_336\speck128rfid_336.ino
# Code with 320-byte plaintext has been written to speck128rfidd\speck128rfid_320\speck128rfid_320.ino
# Code with 304-byte plaintext has been written to speck128rfidd\speck128rfid_304\speck128rfid_304.ino
# Code with 288-byte plaintext has been written to speck128rfidd\speck128rfid_288\speck128rfid_288.ino
# Code with 272-byte plaintext has been written to speck128rfidd\speck128rfid_272\speck128rfid_272.ino
# Code with 256-byte plaintext has been written to speck128rfidd\speck128rfid_256\speck128rfid_256.ino
# Code with 240-byte plaintext has been written to speck128rfidd\speck128rfid_240\speck128rfid_240.ino
# Code with 224-byte plaintext has been written to speck128rfidd\speck128rfid_224\speck128rfid_224.ino
# Code with 208-byte plaintext has been written to speck128rfidd\speck128rfid_208\speck128rfid_208.ino
# Code with 192-byte plaintext has been written to speck128rfidd\speck128rfid_192\speck128rfid_192.ino
# Code with 176-byte plaintext has been written to speck128rfidd\speck128rfid_176\speck128rfid_176.ino
# Code with 160-byte plaintext has been written to speck128rfidd\speck128rfid_160\speck128rfid_160.ino
# Code with 144-byte plaintext has been written to speck128rfidd\speck128rfid_144\speck128rfid_144.ino
# Code with 128-byte plaintext has been written to speck128rfidd\speck128rfid_128\speck128rfid_128.ino
# Code with 112-byte plaintext has been written to speck128rfidd\speck128rfid_112\speck128rfid_112.ino
# Code with 96-byte plaintext has been written to speck128rfidd\speck128rfid_96\speck128rfid_96.ino
# Code with 80-byte plaintext has been written to speck128rfidd\speck128rfid_80\speck128rfid_80.ino
# Code with 64-byte plaintext has been written to speck128rfidd\speck128rfid_64\speck128rfid_64.ino
# Code with 48-byte plaintext has been written to speck128rfidd\speck128rfid_48\speck128rfid_48.ino
# Code with 32-byte plaintext has been written to speck128rfidd\speck128rfid_32\speck128rfid_32.ino
# Code with 16-byte plaintext has been written to speck128rfidd\speck128rfid_16\speck128rfid_16.ino
# Code with 400-byte plaintext has been written to speck128rfide\speck128rfid_400\speck128rfid_400.ino
# Code with 384-byte plaintext has been written to speck128rfide\speck128rfid_384\speck128rfid_384.ino
# Code with 368-byte plaintext has been written to speck128rfide\speck128rfid_368\speck128rfid_368.ino
# Code with 352-byte plaintext has been written to speck128rfide\speck128rfid_352\speck128rfid_352.ino
# Code with 336-byte plaintext has been written to speck128rfide\speck128rfid_336\speck128rfid_336.ino
# Code with 320-byte plaintext has been written to speck128rfide\speck128rfid_320\speck128rfid_320.ino
# Code with 304-byte plaintext has been written to speck128rfide\speck128rfid_304\speck128rfid_304.ino
# Code with 288-byte plaintext has been written to speck128rfide\speck128rfid_288\speck128rfid_288.ino
# Code with 272-byte plaintext has been written to speck128rfide\speck128rfid_272\speck128rfid_272.ino
# Code with 256-byte plaintext has been written to speck128rfide\speck128rfid_256\speck128rfid_256.ino
# Code with 240-byte plaintext has been written to speck128rfide\speck128rfid_240\speck128rfid_240.ino
# Code with 224-byte plaintext has been written to speck128rfide\speck128rfid_224\speck128rfid_224.ino
# Code with 208-byte plaintext has been written to speck128rfide\speck128rfid_208\speck128rfid_208.ino
# Code with 192-byte plaintext has been written to speck128rfide\speck128rfid_192\speck128rfid_192.ino
# Code with 176-byte plaintext has been written to speck128rfide\speck128rfid_176\speck128rfid_176.ino
# Code with 160-byte plaintext has been written to speck128rfide\speck128rfid_160\speck128rfid_160.ino
# Code with 144-byte plaintext has been written to speck128rfide\speck128rfid_144\speck128rfid_144.ino
# Code with 128-byte plaintext has been written to speck128rfide\speck128rfid_128\speck128rfid_128.ino
# Code with 112-byte plaintext has been written to speck128rfide\speck128rfid_112\speck128rfid_112.ino
# Code with 96-byte plaintext has been written to speck128rfide\speck128rfid_96\speck128rfid_96.ino
# Code with 80-byte plaintext has been written to speck128rfide\speck128rfid_80\speck128rfid_80.ino
# Code with 64-byte plaintext has been written to speck128rfide\speck128rfid_64\speck128rfid_64.ino
# Code with 48-byte plaintext has been written to speck128rfide\speck128rfid_48\speck128rfid_48.ino
# Code with 32-byte plaintext has been written to speck128rfide\speck128rfid_32\speck128rfid_32.ino
# Code with 16-byte plaintext has been written to speck128rfide\speck128rfid_16\speck128rfid_16.ino

# %%
import subprocess
import serial
import csv
import re
import time
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
# a

import os
import re
import subprocess
import time
import serial

# Configurations
port = "COM18"
baud_rate = 9600
base_folder = "speck128rfida"  # Hanya folder yang diinginkan
arduino_cli_path = r"C:\Program Files\Arduino IDE\resources\app\lib\backend\resources\arduino-cli.exe"
log_base_folder = "../../logs"

# Ensure the base log folder exists
os.makedirs(log_base_folder, exist_ok=True)

def compile_and_upload(sketch_path, log_file):
    # Compile and upload code to Arduino
    compile_command = [arduino_cli_path, "compile", "--fqbn", "arduino:avr:nano", sketch_path]
    upload_command = [arduino_cli_path, "upload", "-p", port, "--fqbn", "arduino:avr:nano", sketch_path]

    # Run compile command and capture output for memory usage
    compile_result = subprocess.run(compile_command, capture_output=True, text=True)
    upload_result = subprocess.run(upload_command, capture_output=True, text=True)
    time.sleep(2)  # Wait for Arduino to reset

    # Extract flash and RAM usage from the compile output
    flash_usage = ram_usage = None
    flash_match = re.search(r"Sketch uses (\d+) bytes.*Maximum is (\d+) bytes", compile_result.stdout)
    ram_match = re.search(r"Global variables use (\d+) bytes.*Maximum is (\d+) bytes", compile_result.stdout)
    if flash_match and ram_match:
        flash_usage = f"{flash_match.group(1)} / {flash_match.group(2)} bytes"
        ram_usage = f"{ram_match.group(1)} / {ram_match.group(2)} bytes"
        print(f"{os.path.basename(sketch_path)} - Flash: {flash_usage}, RAM: {ram_usage}")
    else:
        print(f"{os.path.basename(sketch_path)} - Failed to retrieve memory usage information")

    # Write Flash and RAM info to the log file
    with open(log_file, "w") as f:
        if flash_usage and ram_usage:
            f.write(f"Flash Usage: {flash_usage}, RAM Usage: {ram_usage}\n\n")
        else:
            f.write("Failed to retrieve memory usage information\n\n")

    # Return success or failure based on the result of compile and upload
    return compile_result.returncode == 0 and upload_result.returncode == 0

def record_serial_data(log_file):
    # Capture serial output to a log file
    with serial.Serial(port, baud_rate, timeout=1) as ser, open(log_file, 'a') as file:  # Open in append mode
        ser.flushInput()  # Clear any leftover data in the buffer
        start_time = time.time()
        while time.time() - start_time < 10:  # 10-second timeout
            if ser.in_waiting > 0:
                line = ser.readline().decode('utf-8').strip()
                file.write(line + '\n')
                print(line)
                if 'selesai' in line.lower():
                    break
        time.sleep(1)  # Additional wait to ensure all data is captured

# Define log folder for the current base folder
log_folder = os.path.join(log_base_folder, f"logs_{base_folder}")
os.makedirs(log_folder, exist_ok=True)  # Create folder if it doesn't exist

# Get sorted list of subfolders in the base folder
subfolders = sorted(
    [folder for folder in os.listdir(base_folder) if os.path.isdir(os.path.join(base_folder, folder))],
    key=lambda x: int(x.split('_')[1])
)

for folder_name in subfolders:
    sketch_path = os.path.join(base_folder, folder_name, f"{folder_name}.ino")
    if os.path.isfile(sketch_path):
        print(f"Running {folder_name} in {base_folder}...")

        # Define log file path for the current sketch
        log_file = os.path.join(log_folder, f"{folder_name}.txt")

        # Compile and upload; skip if failed
        if compile_and_upload(sketch_path, log_file):
            # Capture serial output
            record_serial_data(log_file)
        else:
            print(f"{folder_name} failed to run in {base_folder}.\n")
    else:
        print(f"File {folder_name}.ino not found in {folder_name} within {base_folder}")

print("Data collection complete.")
# Out:
# Running speck128rfid_16 in speck128rfida...
# speck128rfid_16.ino - Flash: 15104 / 30720 bytes, RAM: 1107 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83
# Encryption Completed in 460 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 472 us
# Memory Usage = 1142 B
#
# Encryption Voltage: 4.17 V
# Encryption Current: 7.20 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.20 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_32 in speck128rfida...
# speck128rfid_32.ino - Flash: 15178 / 30720 bytes, RAM: 1139 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 636 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 656 us
# Memory Usage = 1174 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.20 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.17 V
# Decryption Current: 7.10 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_48 in speck128rfida...
# speck128rfid_48.ino - Flash: 15192 / 30720 bytes, RAM: 1171 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 816 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 844 us
# Memory Usage = 1208 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.10 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 6.90 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_64 in speck128rfida...
# speck128rfid_64.ino - Flash: 15220 / 30720 bytes, RAM: 1203 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 996 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 1036 us
# Memory Usage = 1240 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.00 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.00 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_80 in speck128rfida...
# speck128rfid_80.ino - Flash: 15220 / 30720 bytes, RAM: 1235 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 1176 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 1220 us
# Memory Usage = 1272 B
#
# Encryption Voltage: 4.17 V
# Encryption Current: 7.40 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.30 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_96 in speck128rfida...
# speck128rfid_96.ino - Flash: 15220 / 30720 bytes, RAM: 1267 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 1352 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 1404 us
# Memory Usage = 1304 B
#
# Encryption Voltage: 4.17 V
# Encryption Current: 7.00 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.20 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_112 in speck128rfida...
# speck128rfid_112.ino - Flash: 15268 / 30720 bytes, RAM: 1299 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 1528 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 1588 us
# Memory Usage = 1336 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.40 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.40 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_128 in speck128rfida...
# speck128rfid_128.ino - Flash: 15294 / 30720 bytes, RAM: 1331 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 1704 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 1772 us
# Memory Usage = 1368 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 6.90 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.30 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_144 in speck128rfida...
# speck128rfid_144.ino - Flash: 15292 / 30720 bytes, RAM: 1363 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 1888 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 1960 us
# Memory Usage = 1400 B
#
# Encryption Voltage: 4.17 V
# Encryption Current: 7.00 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.20 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_160 in speck128rfida...
# speck128rfid_160.ino - Flash: 15292 / 30720 bytes, RAM: 1395 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 2064 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 2156 us
# Memory Usage = 1432 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.10 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.00 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_176 in speck128rfida...
# speck128rfid_176.ino - Flash: 15292 / 30720 bytes, RAM: 1427 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 2236 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 2336 us
# Memory Usage = 1464 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.10 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 6.90 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_192 in speck128rfida...
# speck128rfid_192.ino - Flash: 15292 / 30720 bytes, RAM: 1459 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 2416 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 2528 us
# Memory Usage = 1496 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.10 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.10 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_208 in speck128rfida...
# speck128rfid_208.ino - Flash: 15292 / 30720 bytes, RAM: 1491 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 2592 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 2712 us
# Memory Usage = 1528 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.10 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.00 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_224 in speck128rfida...
# speck128rfid_224.ino - Flash: 15292 / 30720 bytes, RAM: 1523 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 2776 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 2896 us
# Memory Usage = 1560 B
#
# Encryption Voltage: 4.17 V
# Encryption Current: 6.80 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.10 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_240 in speck128rfida...
# speck128rfid_240.ino - Flash: 15292 / 30720 bytes, RAM: 1555 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 2952 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 3080 us
# Memory Usage = 1592 B
#
# Encryption Voltage: 4.17 V
# Encryption Current: 7.10 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 6.90 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_256 in speck128rfida...
# speck128rfid_256.ino - Flash: 15290 / 30720 bytes, RAM: 1587 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 3128 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 3272 us
# Memory Usage = 1624 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.40 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.30 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_272 in speck128rfida...
# speck128rfid_272.ino - Flash: 15162 / 30720 bytes, RAM: 1619 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 3304 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 3428 us
# Memory Usage = -26030 B
#
# Encryption Voltage: 4.17 V
# Encryption Current: 0.00 mA
# Encryption Power: 0.00 W
#
# Decryption Voltage: 31.74 V
# Decryption Current: 0.00 mA
# Decryption Power: 0.00 W
# selesai
# Running speck128rfid_288 in speck128rfida...
# speck128rfid_288.ino - Flash: 15162 / 30720 bytes, RAM: 1651 / 2048 bytes
# Running speck128rfid_304 in speck128rfida...
# speck128rfid_304.ino - Flash: 15162 / 30720 bytes, RAM: 1683 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 3656 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 3800 us
# Memory Usage = -29863 B
#
# Encryption Voltage: 0.40 V
# Encryption Current: 0.00 mA
# Encryption Power: 0.00 W
#
# Decryption Voltage: 7.17 V
# Decryption Current: 0.00 mA
# Decryption Power: 0.00 W
# selesai
# Running speck128rfid_320 in speck128rfida...
# speck128rfid_320.ino - Flash: 15162 / 30720 bytes, RAM: 1715 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 3840 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 3984 us
# Memory Usage = -195 B
#
# Encryption Voltage: 0.40 V
# Encryption Current: 0.00 mA
# Encryption Power: 0.00 W
#
# Decryption Voltage: 11.26 V
# Decryption Current: 0.00 mA
# Decryption Power: 0.00 W
# selesai
# Running speck128rfid_336 in speck128rfida...
# speck128rfid_336.ino - Flash: 15162 / 30720 bytes, RAM: 1747 / 2048 bytes
# Ciphertext: F7 0C B2 77 A4 3B 82 CF 06 65 46 22 53 20 D3 8F B9 AB A0 7C EA E7 9F AA 42 9D 86 9F BE 4C 58 A8 17 FF C0 A8 A4 09 5D FA 1C BC 6C BD 10 86 1C C2 E6 93 26 A5 D1 6D 98 40 11 FA EE 99 B0 2A 2D 79 CD 9B CF C8 CC 55 AF E1 64 E6 C4 65 C9 38 92 50 87 EA 57 C0 34 89 A8 80 73 76 C3 5E 3F 25 63 C3 F1 5E 55 CD 04 27 10 72 65 AC 4F 09 A1 C7 8D FE 5C 85 0C CA 29 03 94 6E CA 3E D4 71 2F 69 FB E8 C8 F5 DA DE 27 5C DA E1 C0 BA F3 40 24 44 8B 8E 4F 55 FF 9D 7B 42 59 18 AB F9 85 3A 79 D2 7B 01 23 98 F1 96 1C AB EB 09 70 58 24 42 A6 C0 85 55 38 EB 20 C6 4A E9 63 36 EC 0A B2 7B A9 DE 36 90 A3 05 19 3F 90 FC 52 34 50 67 28 DD AE 2F B1 92 C0 52 33 5C 2C 0F BC DE A6 11 D8 8C C6 47 1F 60 49 2F D5 EC A8 17 34 EC 44 C2 6F 4F FF 21 01 CE FB 00 06 08 64 EA AB 6B 4E 21 D8 73 95 B0 62 A5 C4 12 02 88 6F A8 6C 80 D4 B3 47 6E DA 2E EB 07 88 BE 84 2D CA 15 D9 A4 AC 79 CF 80 93 51 61 8F 22 A5 B9 96 72 48 FE 51 11 59 CD D8 FD 53 AF B1 72 69 2F 87 C5 E0 42 16 E4 59 58 0D 55 3F 85 A9 4D 77 48 09 8E 6F 0A BF B9 5F 23 2B 89 CB F0 51
# Encryption Completed in 27676 us
# Decrypted Text: DE F0 68 20 4D E0 82 27 92 3C 9B C5 39 A5 5A 4C F0 1E 64 2E 52 D6 9D BD 9B D5 31 E7 B8 4A 45 12 7C 42 1A CD E8 8E 97 F5 4F D5 53 56 9E 48 E5 D5 2A 5C 11 59 8E 1C 23 18 2A 61 F1 7F B6 3B 7C 8B 9C 82 4B B7 47 6D D3 EE 72 E3 64 6A F7 25 CC EB 76 95 98 87 38 88 DE 47 FE 64 1E 87 D6 55 42 04 47 55 3F 30 AB 76 A1 86 32 89 ED 0E 63 BF 49 E9 B6 91 B4 FF A6 E1 51 DA A3 86 74 75 9D 79 5D F9 EA 6E 40 D4 E8 4F 76 F8 94 54 D4 DE 42 09 20 36 E6 3C F6 34 4B F4 B9 6F 71 74 21 16 5D ED A1 73 39 3A 02 84 BD 1B 61 DC 21 CE 83 0E 2C 88 7C DA C1 51 CC 9F 6D A3 B3 F6 C4 39 AD F0 73 48 02 88 1F 05 32 A4 CB 03 7B 37 A8 5F C7 6D 60 1F 86 3A 93 91 21 F0 71 D9 8B 18 A3 F8 EB FA BF F5 5F 61 E0 C8 E9 F4 37 8D 68 C4 EE BF 23 C9 40 ED A6 37 1A F8 D2 46 C4 24 32 2A 63 E6 55 C9 D0 87 FB 22 98 B2 C9 A9 00 BE 17 AD 11 0E F4 5E 3F 7B 43 5B 66 22 92 97 E9 8F 6C C2 17 5E 3B E0 97 29 47 EF B8 54 00 7C 87 94 32 95 96 8B 4D 90 16 3D E2 5B 82 41 8E 88 CB 6F 72 2B 66 35 9D 1E E0 EE 5E 72 43 01 FF 83 7A AB 3C E3 AC F5 F8 22 7B 07 47 28
# Decryption Completed in 28912 us
# Memory Usage = -195 B
#
# Encryption Voltage: 0.41 V
# Encryption Current: 0.00 mA
# Encryption Power: 0.00 W
#
# Decryption Voltage: 15.36 V
# Decryption Current: 0.00 mA
# Decryption Power: 0.00 W
# selesai
# Running speck128rfid_352 in speck128rfida...
# speck128rfid_352.ino - Flash: 15162 / 30720 bytes, RAM: 1779 / 2048 bytes
# Ciphertext: 50 95 A2 DA DA D8 FF 22 94 FC DB 6E D6 92 2C C5 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20
# Encryption Completed in 1484 us
# Decrypted Text: 87 74 E9 E5 EC E5 A0 71 64 58 CB A6 DB 05 F5 7C B2 35 4C 48 C0 08 21 BB 53 56 C8 42 9A B1 72 DA D4 05 D7 A1 E1 8A C6 43 06 AC 18 78 CB 2A B7 CE F4 DC 09 50 3B CA A7 9B 47 48 B6 56 0E 30 3A CC ED 54 98 EA 11 B1 DE C3 F9 54 1D 51 F3 A5 86 FD 7C 5C 0E 98 AA E1 29 F7 B1 89 D8 FA DA 04 32 86 6B F7 7E DB 8B 6C 02 CA 72 CA 89 9D 5F E8 16 73 FF F9 CF F5 DC CD D0 1A A4 DD D5 2E 80 A9 A7 18 DA 09 70 3C 5E AB DA 2D B4 15 D3 C4 8E D9 F4 5C 28 B9 AB 22 D2 F1 CE D5 94 1D 79 22 A5 44 FE 62 9C 45 CB 40 02 BB 05 2A 2E 6F EB 83 C1 A3 13 BC 7B 49 A9 E4 4E 12 2E 05 32 A4 5F A8 8A FB 03 00 6D 2F 9C C0 E7 95 10 BF DF 52 A2 88 10 36 8D B6 CA 8F BB 58 DC E6 DA EC FE BE 85 5A E5 5B 4C 3C 05 F2 9F C0 B4 7F 64 DE 72 00 3B B3 46 46 35 7F 73 10 F4 22 50 2A C8 E6 E4 F5 41 05 5E B3 15 98 8E CA 22 B9 E3 46 8C D2 A4 00 DE 5B 5C 15 D7 6F 28 05 B3 5A C0 89 6F 0B F2 A9 28 BB E9 B7 98 87 76 21 1F 86 0A D3 73 5B F1 C4 F7 90 F3 D7 E6 84 88 AB 5F D9 4A 57 4E C9 47 D1 04 C4 34 09 76 4E 3C 8B D4 A3 9B 94 30 85 9D 83 EC 96 E8 F7 AE 6B 3A A4 63 74 F2 4F E4 CC 94 72 78 71 5D 07 BB EE
# Decryption Completed in 16768 us
# Memory Usage = 13117 B
#
# Encryption Voltage: 0.42 V
# Encryption Current: 0.00 mA
# Encryption Power: 0.00 W
#
# Decryption Voltage: 19.46 V
# Decryption Current: 0.00 mA
# Decryption Power: 0.00 W
# selesai
# Running speck128rfid_368 in speck128rfida...
# speck128rfid_368.ino - Flash: 15162 / 30720 bytes, RAM: 1811 / 2048 bytes
# Running speck128rfid_384 in speck128rfida...
# speck128rfid_384.ino - Flash: 15162 / 30720 bytes, RAM: 1843 / 2048 bytes
# Running speck128rfid_400 in speck128rfida...
# speck128rfid_400.ino - Flash: 15162 / 30720 bytes, RAM: 1875 / 2048 bytes
# Data collection complete.

# %%
# b

import os
import re
import subprocess
import time
import serial

# Configurations
port = "COM18"
baud_rate = 9600
base_folder = "speck128rfidb"  # Hanya folder yang diinginkan
arduino_cli_path = r"C:\Program Files\Arduino IDE\resources\app\lib\backend\resources\arduino-cli.exe"
log_base_folder = "../../logs"

# Ensure the base log folder exists
os.makedirs(log_base_folder, exist_ok=True)

def compile_and_upload(sketch_path, log_file):
    # Compile and upload code to Arduino
    compile_command = [arduino_cli_path, "compile", "--fqbn", "arduino:avr:nano", sketch_path]
    upload_command = [arduino_cli_path, "upload", "-p", port, "--fqbn", "arduino:avr:nano", sketch_path]

    # Run compile command and capture output for memory usage
    compile_result = subprocess.run(compile_command, capture_output=True, text=True)
    upload_result = subprocess.run(upload_command, capture_output=True, text=True)
    time.sleep(2)  # Wait for Arduino to reset

    # Extract flash and RAM usage from the compile output
    flash_usage = ram_usage = None
    flash_match = re.search(r"Sketch uses (\d+) bytes.*Maximum is (\d+) bytes", compile_result.stdout)
    ram_match = re.search(r"Global variables use (\d+) bytes.*Maximum is (\d+) bytes", compile_result.stdout)
    if flash_match and ram_match:
        flash_usage = f"{flash_match.group(1)} / {flash_match.group(2)} bytes"
        ram_usage = f"{ram_match.group(1)} / {ram_match.group(2)} bytes"
        print(f"{os.path.basename(sketch_path)} - Flash: {flash_usage}, RAM: {ram_usage}")
    else:
        print(f"{os.path.basename(sketch_path)} - Failed to retrieve memory usage information")

    # Write Flash and RAM info to the log file
    with open(log_file, "w") as f:
        if flash_usage and ram_usage:
            f.write(f"Flash Usage: {flash_usage}, RAM Usage: {ram_usage}\n\n")
        else:
            f.write("Failed to retrieve memory usage information\n\n")

    # Return success or failure based on the result of compile and upload
    return compile_result.returncode == 0 and upload_result.returncode == 0

def record_serial_data(log_file):
    # Capture serial output to a log file
    with serial.Serial(port, baud_rate, timeout=1) as ser, open(log_file, 'a') as file:  # Open in append mode
        ser.flushInput()  # Clear any leftover data in the buffer
        start_time = time.time()
        while time.time() - start_time < 10:  # 10-second timeout
            if ser.in_waiting > 0:
                line = ser.readline().decode('utf-8').strip()
                file.write(line + '\n')
                print(line)
                if 'selesai' in line.lower():
                    break
        time.sleep(1)  # Additional wait to ensure all data is captured

# Define log folder for the current base folder
log_folder = os.path.join(log_base_folder, f"logs_{base_folder}")
os.makedirs(log_folder, exist_ok=True)  # Create folder if it doesn't exist

# Get sorted list of subfolders in the base folder
subfolders = sorted(
    [folder for folder in os.listdir(base_folder) if os.path.isdir(os.path.join(base_folder, folder))],
    key=lambda x: int(x.split('_')[1])
)

for folder_name in subfolders:
    sketch_path = os.path.join(base_folder, folder_name, f"{folder_name}.ino")
    if os.path.isfile(sketch_path):
        print(f"Running {folder_name} in {base_folder}...")

        # Define log file path for the current sketch
        log_file = os.path.join(log_folder, f"{folder_name}.txt")

        # Compile and upload; skip if failed
        if compile_and_upload(sketch_path, log_file):
            # Capture serial output
            record_serial_data(log_file)
        else:
            print(f"{folder_name} failed to run in {base_folder}.\n")
    else:
        print(f"File {folder_name}.ino not found in {folder_name} within {base_folder}")

print("Data collection complete.")
# Out:
# Running speck128rfid_16 in speck128rfidb...
# speck128rfid_16.ino - Flash: 15104 / 30720 bytes, RAM: 1107 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83
# Encryption Completed in 460 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 472 us
# Memory Usage = 1142 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.00 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 6.90 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_32 in speck128rfidb...
# speck128rfid_32.ino - Flash: 15178 / 30720 bytes, RAM: 1139 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 636 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 656 us
# Memory Usage = 1174 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.40 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.17 V
# Decryption Current: 7.30 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_48 in speck128rfidb...
# speck128rfid_48.ino - Flash: 15192 / 30720 bytes, RAM: 1171 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 816 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 844 us
# Memory Usage = 1208 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.40 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.20 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_64 in speck128rfidb...
# speck128rfid_64.ino - Flash: 15220 / 30720 bytes, RAM: 1203 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 996 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 1036 us
# Memory Usage = 1240 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.10 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.10 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_80 in speck128rfidb...
# speck128rfid_80.ino - Flash: 15220 / 30720 bytes, RAM: 1235 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 1172 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 1220 us
# Memory Usage = 1272 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.10 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 6.80 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_96 in speck128rfidb...
# speck128rfid_96.ino - Flash: 15220 / 30720 bytes, RAM: 1267 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 1352 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 1404 us
# Memory Usage = 1304 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.20 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.00 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_112 in speck128rfidb...
# speck128rfid_112.ino - Flash: 15268 / 30720 bytes, RAM: 1299 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 1528 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 1588 us
# Memory Usage = 1336 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.00 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.10 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_128 in speck128rfidb...
# speck128rfid_128.ino - Flash: 15294 / 30720 bytes, RAM: 1331 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 1704 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 1776 us
# Memory Usage = 1368 B
#
# Encryption Voltage: 4.17 V
# Encryption Current: 7.00 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 6.90 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_144 in speck128rfidb...
# speck128rfid_144.ino - Flash: 15292 / 30720 bytes, RAM: 1363 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 1884 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 1964 us
# Memory Usage = 1400 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.10 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 6.90 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_160 in speck128rfidb...
# speck128rfid_160.ino - Flash: 15292 / 30720 bytes, RAM: 1395 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 2060 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 2152 us
# Memory Usage = 1432 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.00 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.00 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_176 in speck128rfidb...
# speck128rfid_176.ino - Flash: 15292 / 30720 bytes, RAM: 1427 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 2236 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 2336 us
# Memory Usage = 1464 B
#
# Encryption Voltage: 4.17 V
# Encryption Current: 7.30 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.10 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_192 in speck128rfidb...
# speck128rfid_192.ino - Flash: 15292 / 30720 bytes, RAM: 1459 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 2416 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 2524 us
# Memory Usage = 1496 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 6.90 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.00 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_208 in speck128rfidb...
# speck128rfid_208.ino - Flash: 15292 / 30720 bytes, RAM: 1491 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 2592 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 2712 us
# Memory Usage = 1528 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.10 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.10 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_224 in speck128rfidb...
# speck128rfid_224.ino - Flash: 15292 / 30720 bytes, RAM: 1523 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 2776 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 2896 us
# Memory Usage = 1560 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.00 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.10 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_240 in speck128rfidb...
# speck128rfid_240.ino - Flash: 15292 / 30720 bytes, RAM: 1555 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 2952 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 3080 us
# Memory Usage = 1592 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 6.80 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.20 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_256 in speck128rfidb...
# speck128rfid_256.ino - Flash: 15290 / 30720 bytes, RAM: 1587 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 3128 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 3272 us
# Memory Usage = 1624 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.10 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.15 V
# Decryption Current: 7.00 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_272 in speck128rfidb...
# speck128rfid_272.ino - Flash: 15162 / 30720 bytes, RAM: 1619 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 3304 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 3432 us
# Memory Usage = -26030 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 0.00 mA
# Encryption Power: 0.00 W
#
# Decryption Voltage: 31.74 V
# Decryption Current: 0.00 mA
# Decryption Power: 0.00 W
# selesai
# Running speck128rfid_288 in speck128rfidb...
# speck128rfid_288.ino - Flash: 15162 / 30720 bytes, RAM: 1651 / 2048 bytes
# Running speck128rfid_304 in speck128rfidb...
# speck128rfid_304.ino - Flash: 15162 / 30720 bytes, RAM: 1683 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 3656 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 3800 us
# Memory Usage = -29863 B
#
# Encryption Voltage: 0.40 V
# Encryption Current: 0.00 mA
# Encryption Power: 0.00 W
#
# Decryption Voltage: 7.17 V
# Decryption Current: 0.00 mA
# Decryption Power: 0.00 W
# selesai
# Running speck128rfid_320 in speck128rfidb...
# speck128rfid_320.ino - Flash: 15162 / 30720 bytes, RAM: 1715 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 3840 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 3984 us
# Memory Usage = -195 B
#
# Encryption Voltage: 0.40 V
# Encryption Current: 0.00 mA
# Encryption Power: 0.00 W
#
# Decryption Voltage: 11.26 V
# Decryption Current: 0.00 mA
# Decryption Power: 0.00 W
# selesai
# Running speck128rfid_336 in speck128rfidb...
# speck128rfid_336.ino - Flash: 15162 / 30720 bytes, RAM: 1747 / 2048 bytes
# Ciphertext: F7 0C B2 77 A4 3B 82 CF 06 65 46 22 53 20 D3 8F B9 AB A0 7C EA E7 9F AA 42 9D 86 9F BE 4C 58 A8 17 FF C0 A8 A4 09 5D FA 1C BC 6C BD 10 86 1C C2 E6 93 26 A5 D1 6D 98 40 11 FA EE 99 B0 2A 2D 79 CD 9B CF C8 CC 55 AF E1 64 E6 C4 65 C9 38 92 50 87 EA 57 C0 34 89 A8 80 73 76 C3 5E 3F 25 63 C3 F1 5E 55 CD 04 27 10 72 65 AC 4F 09 A1 C7 8D FE 5C 85 0C CA 29 03 94 6E CA 3E D4 71 2F 69 FB E8 C8 F5 DA DE 27 5C DA E1 C0 BA F3 40 24 44 8B 8E 4F 55 FF 9D 7B 42 59 18 AB F9 85 3A 79 D2 7B 01 23 98 F1 96 1C AB EB 09 70 58 24 42 A6 C0 85 55 38 EB 20 C6 4A E9 63 36 EC 0A B2 7B A9 DE 36 90 A3 05 19 3F 90 FC 52 34 50 67 28 DD AE 2F B1 92 C0 52 33 5C 2C 0F BC DE A6 11 D8 8C C6 47 1F 60 49 2F D5 EC A8 17 34 EC 44 C2 6F 4F FF 21 01 CE FB 00 06 08 64 EA AB 6B 4E 21 D8 73 95 B0 62 A5 C4 12 02 88 6F A8 6C 80 D4 B3 47 6E DA 2E EB 07 88 BE 84 2D CA 15 D9 A4 AC 79 CF 80 93 51 61 8F 22 A5 B9 96 72 48 FE 51 11 59 CD D8 FD 53 AF B1 72 69 2F 87 C5 E0 42 16 E4 59 58 0D 55 3F 85 A9 4D 77 48 09 8E 6F 0A BF B9 5F 23 2B 89 CB F0 51
# Encryption Completed in 27676 us
# Decrypted Text: C4 09 29 ED 06 05 F0 04 EA 9A 67 CD 47 28 57 A1 8C 7E 4E C4 75 FE 8D DE EA 93 A8 DC 55 32 05 9D 4D 43 D4 FF 63 9D 75 7F 4E 08 02 B9 0D 4E 02 9C C9 52 CF 3C A6 6B 72 52 8D 34 F0 A3 E6 6D 93 09 2D E0 18 5D F6 37 27 66 A9 42 1B 6D 25 CB E5 01 34 86 74 F5 5E 9C 34 2F FD 47 CD BC D1 65 B0 B0 4C 4E DA AB F8 B9 45 22 D5 10 70 0D 85 9F 95 1F 29 43 24 7A 99 D8 43 4D C3 5E 96 1B A8 5E 84 88 26 BF A3 B7 B9 4E 60 6A 42 B6 30 B1 68 FD 17 C9 CE A6 02 21 52 EC 67 61 6C D4 8C 4C 15 69 EE 9A BF 75 8D C0 92 F3 25 46 F9 8D 95 CB 70 17 1B 06 6D E5 73 F2 79 14 86 63 D2 33 2B 56 5B F0 CC 9D CF 4A 8D 46 40 77 0C F6 7F 73 28 19 25 BD 3B 87 DD ED 18 22 55 8C A3 3D BB CA 61 60 99 E3 C4 EB 77 1D 1C 77 D5 1F FC 44 26 50 C4 05 73 8E 89 D8 B8 49 98 E7 D9 39 97 4E CC 2F 9A 3E A7 AE 03 DE A8 EC 7A 3C 5B 3A 8A 6B F6 FC 4D 83 77 CE 1B 22 DD 21 26 9D BF E8 57 1C 62 7A 97 BF 54 D4 96 FF B6 57 E7 AC 4D DC EB 19 D0 C5 FD 69 02 D5 BA 6A 1F 0F A3 86 33 0D 11 8C 06 30 24 5D 6A DE FA 49 C5 FA E7 D1 94 F0 4D 1F 2F C2 19 3C 6A 5A 98 28
# Decryption Completed in 28912 us
# Memory Usage = -195 B
#
# Encryption Voltage: 0.41 V
# Encryption Current: 0.00 mA
# Encryption Power: 0.00 W
#
# Decryption Voltage: 15.36 V
# Decryption Current: 0.00 mA
# Decryption Power: 0.00 W
# selesai
# Running speck128rfid_352 in speck128rfidb...
# speck128rfid_352.ino - Flash: 15162 / 30720 bytes, RAM: 1779 / 2048 bytes
# Ciphertext: 50 95 A2 DA DA D8 FF 22 94 FC DB 6E D6 92 2C C5 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20
# Encryption Completed in 1484 us
# Decrypted Text: 87 74 E9 E5 EC E5 A0 71 64 58 CB A6 DB 05 F5 7C B2 35 4C 48 C0 08 21 BB 53 56 C8 42 9A B1 72 DA D4 05 D7 A1 E1 8A C6 43 06 AC 18 78 CB 2A B7 CE F4 DC 09 50 3B CA A7 9B 47 48 B6 56 0E 30 3A CC ED 54 98 EA 11 B1 DE C3 F9 54 1D 51 F3 A5 86 FD 7C 5C 0E 98 AA E1 29 F7 B1 89 D8 FA DA 04 32 86 6B F7 7E DB 8B 6C 02 CA 72 CA 89 9D 5F E8 16 73 FF F9 CF F5 DC CD D0 1A A4 DD D5 2E 80 A9 A7 18 DA 09 70 3C 5E AB DA 2D B4 15 D3 C4 8E D9 F4 5C 28 B9 AB 22 D2 F1 CE D5 94 1D 79 22 A5 44 FE 62 9C 45 CB 40 02 BB 05 2A 2E 6F EB 83 C1 A3 13 BC 7B 49 A9 E4 4E 12 2E 05 32 A4 5F A8 8A FB 03 00 6D 2F 9C C0 E7 95 10 BF DF 52 A2 88 10 36 8D B6 CA 8F BB 58 DC E6 DA EC FE BE 85 5A E5 5B 4C 3C 05 F2 9F C0 B4 7F 64 DE 72 00 3B B3 46 46 35 7F 73 10 F4 22 50 2A C8 E6 E4 F5 41 05 5E B3 15 98 8E CA 22 B9 E3 46 8C D2 A4 00 DE 5B 5C 15 D7 6F 28 05 B3 5A C0 89 6F 0B F2 A9 28 BB E9 B7 98 87 76 21 1F 86 0A D3 73 5B F1 C4 F7 90 F3 D7 E6 84 88 AB 5F D9 4A 57 4E C9 47 D1 04 C4 34 09 76 4E 3C 8B D4 A3 9B 94 30 85 9D 83 EC 96 E8 F7 AE 6B 3A A4 63 74 F2 4F E4 CC 94 72 78 71 5D 07 BB EE
# Decryption Completed in 16768 us
# Memory Usage = 13117 B
#
# Encryption Voltage: 0.42 V
# Encryption Current: 0.00 mA
# Encryption Power: 0.00 W
#
# Decryption Voltage: 19.46 V
# Decryption Current: 0.00 mA
# Decryption Power: 0.00 W
# selesai
# Running speck128rfid_368 in speck128rfidb...
# speck128rfid_368.ino - Flash: 15162 / 30720 bytes, RAM: 1811 / 2048 bytes
# Running speck128rfid_384 in speck128rfidb...
# speck128rfid_384.ino - Flash: 15162 / 30720 bytes, RAM: 1843 / 2048 bytes
# Running speck128rfid_400 in speck128rfidb...
# speck128rfid_400.ino - Flash: 15162 / 30720 bytes, RAM: 1875 / 2048 bytes
# Data collection complete.

# %%
# c

import os
import re
import subprocess
import time
import serial

# Configurations
port = "COM18"
baud_rate = 9600
base_folder = "speck128rfidc"  # Hanya folder yang diinginkan
arduino_cli_path = r"C:\Program Files\Arduino IDE\resources\app\lib\backend\resources\arduino-cli.exe"
log_base_folder = "../../logs"

# Ensure the base log folder exists
os.makedirs(log_base_folder, exist_ok=True)

def compile_and_upload(sketch_path, log_file):
    # Compile and upload code to Arduino
    compile_command = [arduino_cli_path, "compile", "--fqbn", "arduino:avr:nano", sketch_path]
    upload_command = [arduino_cli_path, "upload", "-p", port, "--fqbn", "arduino:avr:nano", sketch_path]

    # Run compile command and capture output for memory usage
    compile_result = subprocess.run(compile_command, capture_output=True, text=True)
    upload_result = subprocess.run(upload_command, capture_output=True, text=True)
    time.sleep(2)  # Wait for Arduino to reset

    # Extract flash and RAM usage from the compile output
    flash_usage = ram_usage = None
    flash_match = re.search(r"Sketch uses (\d+) bytes.*Maximum is (\d+) bytes", compile_result.stdout)
    ram_match = re.search(r"Global variables use (\d+) bytes.*Maximum is (\d+) bytes", compile_result.stdout)
    if flash_match and ram_match:
        flash_usage = f"{flash_match.group(1)} / {flash_match.group(2)} bytes"
        ram_usage = f"{ram_match.group(1)} / {ram_match.group(2)} bytes"
        print(f"{os.path.basename(sketch_path)} - Flash: {flash_usage}, RAM: {ram_usage}")
    else:
        print(f"{os.path.basename(sketch_path)} - Failed to retrieve memory usage information")

    # Write Flash and RAM info to the log file
    with open(log_file, "w") as f:
        if flash_usage and ram_usage:
            f.write(f"Flash Usage: {flash_usage}, RAM Usage: {ram_usage}\n\n")
        else:
            f.write("Failed to retrieve memory usage information\n\n")

    # Return success or failure based on the result of compile and upload
    return compile_result.returncode == 0 and upload_result.returncode == 0

def record_serial_data(log_file):
    # Capture serial output to a log file
    with serial.Serial(port, baud_rate, timeout=1) as ser, open(log_file, 'a') as file:  # Open in append mode
        ser.flushInput()  # Clear any leftover data in the buffer
        start_time = time.time()
        while time.time() - start_time < 10:  # 10-second timeout
            if ser.in_waiting > 0:
                line = ser.readline().decode('utf-8').strip()
                file.write(line + '\n')
                print(line)
                if 'selesai' in line.lower():
                    break
        time.sleep(1)  # Additional wait to ensure all data is captured

# Define log folder for the current base folder
log_folder = os.path.join(log_base_folder, f"logs_{base_folder}")
os.makedirs(log_folder, exist_ok=True)  # Create folder if it doesn't exist

# Get sorted list of subfolders in the base folder
subfolders = sorted(
    [folder for folder in os.listdir(base_folder) if os.path.isdir(os.path.join(base_folder, folder))],
    key=lambda x: int(x.split('_')[1])
)

for folder_name in subfolders:
    sketch_path = os.path.join(base_folder, folder_name, f"{folder_name}.ino")
    if os.path.isfile(sketch_path):
        print(f"Running {folder_name} in {base_folder}...")

        # Define log file path for the current sketch
        log_file = os.path.join(log_folder, f"{folder_name}.txt")

        # Compile and upload; skip if failed
        if compile_and_upload(sketch_path, log_file):
            # Capture serial output
            record_serial_data(log_file)
        else:
            print(f"{folder_name} failed to run in {base_folder}.\n")
    else:
        print(f"File {folder_name}.ino not found in {folder_name} within {base_folder}")

print("Data collection complete.")
# Out:
# Running speck128rfid_16 in speck128rfidc...
# speck128rfid_16.ino - Flash: 15104 / 30720 bytes, RAM: 1107 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83
# Encryption Completed in 460 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 472 us
# Memory Usage = 1142 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.10 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.00 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_32 in speck128rfidc...
# speck128rfid_32.ino - Flash: 15178 / 30720 bytes, RAM: 1139 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 636 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 656 us
# Memory Usage = 1174 B
#
# Encryption Voltage: 4.17 V
# Encryption Current: 7.10 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.17 V
# Decryption Current: 7.00 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_48 in speck128rfidc...
# speck128rfid_48.ino - Flash: 15192 / 30720 bytes, RAM: 1171 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 824 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 844 us
# Memory Usage = 1208 B
#
# Encryption Voltage: 4.17 V
# Encryption Current: 7.10 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.10 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_64 in speck128rfidc...
# speck128rfid_64.ino - Flash: 15220 / 30720 bytes, RAM: 1203 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 996 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 1036 us
# Memory Usage = 1240 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.20 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.00 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_80 in speck128rfidc...
# speck128rfid_80.ino - Flash: 15220 / 30720 bytes, RAM: 1235 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 1176 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 1220 us
# Memory Usage = 1272 B
#
# Encryption Voltage: 4.17 V
# Encryption Current: 7.00 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 6.90 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_96 in speck128rfidc...
# speck128rfid_96.ino - Flash: 15220 / 30720 bytes, RAM: 1267 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 1352 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 1404 us
# Memory Usage = 1304 B
#
# Encryption Voltage: 4.17 V
# Encryption Current: 7.00 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.10 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_112 in speck128rfidc...
# speck128rfid_112.ino - Flash: 15268 / 30720 bytes, RAM: 1299 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 1528 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 1588 us
# Memory Usage = 1336 B
#
# Encryption Voltage: 4.17 V
# Encryption Current: 6.90 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.17 V
# Decryption Current: 7.30 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_128 in speck128rfidc...
# speck128rfid_128.ino - Flash: 15294 / 30720 bytes, RAM: 1331 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 1704 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 1772 us
# Memory Usage = 1368 B
#
# Encryption Voltage: 4.17 V
# Encryption Current: 7.00 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.10 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_144 in speck128rfidc...
# speck128rfid_144.ino - Flash: 15292 / 30720 bytes, RAM: 1363 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 1884 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 1964 us
# Memory Usage = 1400 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.30 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.10 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_160 in speck128rfidc...
# speck128rfid_160.ino - Flash: 15292 / 30720 bytes, RAM: 1395 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 2060 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 2152 us
# Memory Usage = 1432 B
#
# Encryption Voltage: 4.17 V
# Encryption Current: 7.10 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.17 V
# Decryption Current: 7.10 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_176 in speck128rfidc...
# speck128rfid_176.ino - Flash: 15292 / 30720 bytes, RAM: 1427 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 2236 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 2336 us
# Memory Usage = 1464 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 6.80 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.00 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_192 in speck128rfidc...
# speck128rfid_192.ino - Flash: 15292 / 30720 bytes, RAM: 1459 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 2416 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 2524 us
# Memory Usage = 1496 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.10 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.20 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_208 in speck128rfidc...
# speck128rfid_208.ino - Flash: 15292 / 30720 bytes, RAM: 1491 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 2592 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 2712 us
# Memory Usage = 1528 B
#
# Encryption Voltage: 4.17 V
# Encryption Current: 7.10 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 6.90 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_224 in speck128rfidc...
# speck128rfid_224.ino - Flash: 15292 / 30720 bytes, RAM: 1523 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 2776 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 2896 us
# Memory Usage = 1560 B
#
# Encryption Voltage: 4.17 V
# Encryption Current: 6.90 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.00 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_240 in speck128rfidc...
# speck128rfid_240.ino - Flash: 15292 / 30720 bytes, RAM: 1555 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 2952 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 3080 us
# Memory Usage = 1592 B
#
# Encryption Voltage: 4.17 V
# Encryption Current: 7.00 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.17 V
# Decryption Current: 7.10 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_256 in speck128rfidc...
# speck128rfid_256.ino - Flash: 15290 / 30720 bytes, RAM: 1587 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 3128 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 3272 us
# Memory Usage = 1624 B
#
# Encryption Voltage: 4.17 V
# Encryption Current: 7.00 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.10 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_272 in speck128rfidc...
# speck128rfid_272.ino - Flash: 15162 / 30720 bytes, RAM: 1619 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 3304 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 3432 us
# Memory Usage = -26030 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 0.00 mA
# Encryption Power: 0.00 W
#
# Decryption Voltage: 31.74 V
# Decryption Current: 0.00 mA
# Decryption Power: 0.00 W
# selesai
# Running speck128rfid_288 in speck128rfidc...
# speck128rfid_288.ino - Flash: 15162 / 30720 bytes, RAM: 1651 / 2048 bytes
# Running speck128rfid_304 in speck128rfidc...
# speck128rfid_304.ino - Flash: 15162 / 30720 bytes, RAM: 1683 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 3656 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 3800 us
# Memory Usage = -29863 B
#
# Encryption Voltage: 0.40 V
# Encryption Current: 0.00 mA
# Encryption Power: 0.00 W
#
# Decryption Voltage: 7.17 V
# Decryption Current: 0.00 mA
# Decryption Power: 0.00 W
# selesai
# Running speck128rfid_320 in speck128rfidc...
# speck128rfid_320.ino - Flash: 15162 / 30720 bytes, RAM: 1715 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 3840 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 3984 us
# Memory Usage = -195 B
#
# Encryption Voltage: 0.40 V
# Encryption Current: 0.00 mA
# Encryption Power: 0.00 W
#
# Decryption Voltage: 11.26 V
# Decryption Current: 0.00 mA
# Decryption Power: 0.00 W
# selesai
# Running speck128rfid_336 in speck128rfidc...
# speck128rfid_336.ino - Flash: 15162 / 30720 bytes, RAM: 1747 / 2048 bytes
# Ciphertext: F7 0C B2 77 A4 3B 82 CF 06 65 46 22 53 20 D3 8F B9 AB A0 7C EA E7 9F AA 42 9D 86 9F BE 4C 58 A8 17 FF C0 A8 A4 09 5D FA 1C BC 6C BD 10 86 1C C2 E6 93 26 A5 D1 6D 98 40 11 FA EE 99 B0 2A 2D 79 CD 9B CF C8 CC 55 AF E1 64 E6 C4 65 C9 38 92 50 87 EA 57 C0 34 89 A8 80 73 76 C3 5E 3F 25 63 C3 F1 5E 55 CD 04 27 10 72 65 AC 4F 09 A1 C7 8D FE 5C 85 0C CA 29 03 94 6E CA 3E D4 71 2F 69 FB E8 C8 F5 DA DE 27 5C DA E1 C0 BA F3 40 24 44 8B 8E 4F 55 FF 9D 7B 42 59 18 AB F9 85 3A 79 D2 7B 01 23 98 F1 96 1C AB EB 09 70 58 24 42 A6 C0 85 55 38 EB 20 C6 4A E9 63 36 EC 0A B2 7B A9 DE 36 90 A3 05 19 3F 90 FC 52 34 50 67 28 DD AE 2F B1 92 C0 52 33 5C 2C 0F BC DE A6 11 D8 8C C6 47 1F 60 49 2F D5 EC A8 17 34 EC 44 C2 6F 4F FF 21 01 CE FB 00 06 08 64 EA AB 6B 4E 21 D8 73 95 B0 62 A5 C4 12 02 88 6F A8 6C 80 D4 B3 47 6E DA 2E EB 07 88 BE 84 2D CA 15 D9 A4 AC 79 CF 80 93 51 61 8F 22 A5 B9 96 72 48 FE 51 11 59 CD D8 FD 53 AF B1 72 69 2F 87 C5 E0 42 16 E4 59 58 0D 55 3F 85 A9 4D 77 48 09 8E 6F 0A BF B9 5F 23 2B 89 CB F0 51
# Encryption Completed in 27676 us
# Decrypted Text: 5E BE A7 D8 CC 94 6F C5 D7 15 C9 E5 2A DC 95 71 7C 47 B2 D0 46 F3 B1 EB 42 C2 11 2C 0A 4C A9 0B C8 E1 7A 8F C9 0D A1 7E 19 D1 85 55 5E 3D 5D 49 46 D7 FA 59 FA 85 B9 7C 82 C0 35 97 44 D5 55 EE A1 8B F2 B7 BD EF 7D 15 23 EA 5D A8 EE 67 B2 8E 79 8D 50 6B 45 15 50 82 BF 3B 65 62 5B 9B 1E 54 B4 8B 77 65 62 97 8A FE 85 61 85 0A CC 08 0B E0 44 9B CB 3A 48 F3 02 E8 64 3D 94 4C 13 5F 58 B2 17 36 B5 25 6B 70 A2 5B 74 C0 54 60 39 66 A8 B7 28 1F DB B9 5B C9 B8 93 0F A7 5D A3 28 D3 9A 6F 39 5E F9 4A B2 7B ED 4D 9D AC C8 C3 E9 2D 9F A7 F9 54 C7 FE AB 2B FC F4 5E 20 BB 90 43 7D 30 6E 5E A6 DF DF EB 9C 87 0D 51 64 A1 A1 9E 98 40 46 81 98 09 0F 49 17 AB 0C C2 C9 AB A1 B0 BB 2E A4 30 8B F9 65 09 A9 D9 7B ED 82 E7 63 69 B0 4E 15 56 6F 62 47 03 F2 CE 19 33 86 E5 CA 0A 31 96 55 12 D2 55 2F 79 2C A0 F4 58 16 DE 93 38 F2 08 0D 2B 97 15 84 B6 50 63 3B 02 1C 42 6A 50 57 BE 25 6E 67 AC C2 71 3D 33 A1 01 78 30 02 9D DB 82 A6 8F F0 A1 8F 66 72 90 7F 99 C4 7D 93 79 70 98 FE 12 B9 9F 95 BF 22 06 98 62 A7 4A ED A5 47 8F 87
# Decryption Completed in 28912 us
# Memory Usage = -195 B
#
# Encryption Voltage: 0.41 V
# Encryption Current: 0.00 mA
# Encryption Power: 0.00 W
#
# Decryption Voltage: 15.36 V
# Decryption Current: 0.00 mA
# Decryption Power: 0.00 W
# selesai
# Running speck128rfid_352 in speck128rfidc...
# speck128rfid_352.ino - Flash: 15162 / 30720 bytes, RAM: 1779 / 2048 bytes
# Ciphertext: 50 95 A2 DA DA D8 FF 22 94 FC DB 6E D6 92 2C C5 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20
# Encryption Completed in 1484 us
# Decrypted Text: 87 74 E9 E5 EC E5 A0 71 64 58 CB A6 DB 05 F5 7C B2 35 4C 48 C0 08 21 BB 53 56 C8 42 9A B1 72 DA D4 05 D7 A1 E1 8A C6 43 06 AC 18 78 CB 2A B7 CE F4 DC 09 50 3B CA A7 9B 47 48 B6 56 0E 30 3A CC ED 54 98 EA 11 B1 DE C3 F9 54 1D 51 F3 A5 86 FD 7C 5C 0E 98 AA E1 29 F7 B1 89 D8 FA DA 04 32 86 6B F7 7E DB 8B 6C 02 CA 72 CA 89 9D 5F E8 16 73 FF F9 CF F5 DC CD D0 1A A4 DD D5 2E 80 A9 A7 18 DA 09 70 3C 5E AB DA 2D B4 15 D3 C4 8E D9 F4 5C 28 B9 AB 22 D2 F1 CE D5 94 1D 79 22 A5 44 FE 62 9C 45 CB 40 02 BB 05 2A 2E 6F EB 83 C1 A3 13 BC 7B 49 A9 E4 4E 12 2E 05 32 A4 5F A8 8A FB 03 00 6D 2F 9C C0 E7 95 10 BF DF 52 A2 88 10 36 8D B6 CA 8F BB 58 DC E6 DA EC FE BE 85 5A E5 5B 4C 3C 05 F2 9F C0 B4 7F 64 DE 72 00 3B B3 46 46 35 7F 73 10 F4 22 50 2A C8 E6 E4 F5 41 05 5E B3 15 98 8E CA 22 B9 E3 46 8C D2 A4 00 DE 5B 5C 15 D7 6F 28 05 B3 5A C0 89 6F 0B F2 A9 28 BB E9 B7 98 87 76 21 1F 86 0A D3 73 5B F1 C4 F7 90 F3 D7 E6 84 88 AB 5F D9 4A 57 4E C9 47 D1 04 C4 34 09 76 4E 3C 8B D4 A3 9B 94 30 85 9D 83 EC 96 E8 F7 AE 6B 3A A4 63 74 F2 4F E4 CC 94 72 78 71 5D 07 BB EE
# Decryption Completed in 16768 us
# Memory Usage = 13117 B
#
# Encryption Voltage: 0.42 V
# Encryption Current: 0.00 mA
# Encryption Power: 0.00 W
#
# Decryption Voltage: 19.46 V
# Decryption Current: 0.00 mA
# Decryption Power: 0.00 W
# selesai
# Running speck128rfid_368 in speck128rfidc...
# speck128rfid_368.ino - Flash: 15162 / 30720 bytes, RAM: 1811 / 2048 bytes
# Running speck128rfid_384 in speck128rfidc...
# speck128rfid_384.ino - Flash: 15162 / 30720 bytes, RAM: 1843 / 2048 bytes
# Running speck128rfid_400 in speck128rfidc...
# speck128rfid_400.ino - Flash: 15162 / 30720 bytes, RAM: 1875 / 2048 bytes
# Data collection complete.

# %%
# d

import os
import re
import subprocess
import time
import serial

# Configurations
port = "COM18"
baud_rate = 9600
base_folder = "speck128rfidd"  # Hanya folder yang diinginkan
arduino_cli_path = r"C:\Program Files\Arduino IDE\resources\app\lib\backend\resources\arduino-cli.exe"
log_base_folder = "../../logs"

# Ensure the base log folder exists
os.makedirs(log_base_folder, exist_ok=True)

def compile_and_upload(sketch_path, log_file):
    # Compile and upload code to Arduino
    compile_command = [arduino_cli_path, "compile", "--fqbn", "arduino:avr:nano", sketch_path]
    upload_command = [arduino_cli_path, "upload", "-p", port, "--fqbn", "arduino:avr:nano", sketch_path]

    # Run compile command and capture output for memory usage
    compile_result = subprocess.run(compile_command, capture_output=True, text=True)
    upload_result = subprocess.run(upload_command, capture_output=True, text=True)
    time.sleep(2)  # Wait for Arduino to reset

    # Extract flash and RAM usage from the compile output
    flash_usage = ram_usage = None
    flash_match = re.search(r"Sketch uses (\d+) bytes.*Maximum is (\d+) bytes", compile_result.stdout)
    ram_match = re.search(r"Global variables use (\d+) bytes.*Maximum is (\d+) bytes", compile_result.stdout)
    if flash_match and ram_match:
        flash_usage = f"{flash_match.group(1)} / {flash_match.group(2)} bytes"
        ram_usage = f"{ram_match.group(1)} / {ram_match.group(2)} bytes"
        print(f"{os.path.basename(sketch_path)} - Flash: {flash_usage}, RAM: {ram_usage}")
    else:
        print(f"{os.path.basename(sketch_path)} - Failed to retrieve memory usage information")

    # Write Flash and RAM info to the log file
    with open(log_file, "w") as f:
        if flash_usage and ram_usage:
            f.write(f"Flash Usage: {flash_usage}, RAM Usage: {ram_usage}\n\n")
        else:
            f.write("Failed to retrieve memory usage information\n\n")

    # Return success or failure based on the result of compile and upload
    return compile_result.returncode == 0 and upload_result.returncode == 0

def record_serial_data(log_file):
    # Capture serial output to a log file
    with serial.Serial(port, baud_rate, timeout=1) as ser, open(log_file, 'a') as file:  # Open in append mode
        ser.flushInput()  # Clear any leftover data in the buffer
        start_time = time.time()
        while time.time() - start_time < 10:  # 10-second timeout
            if ser.in_waiting > 0:
                line = ser.readline().decode('utf-8').strip()
                file.write(line + '\n')
                print(line)
                if 'selesai' in line.lower():
                    break
        time.sleep(1)  # Additional wait to ensure all data is captured

# Define log folder for the current base folder
log_folder = os.path.join(log_base_folder, f"logs_{base_folder}")
os.makedirs(log_folder, exist_ok=True)  # Create folder if it doesn't exist

# Get sorted list of subfolders in the base folder
subfolders = sorted(
    [folder for folder in os.listdir(base_folder) if os.path.isdir(os.path.join(base_folder, folder))],
    key=lambda x: int(x.split('_')[1])
)

for folder_name in subfolders:
    sketch_path = os.path.join(base_folder, folder_name, f"{folder_name}.ino")
    if os.path.isfile(sketch_path):
        print(f"Running {folder_name} in {base_folder}...")

        # Define log file path for the current sketch
        log_file = os.path.join(log_folder, f"{folder_name}.txt")

        # Compile and upload; skip if failed
        if compile_and_upload(sketch_path, log_file):
            # Capture serial output
            record_serial_data(log_file)
        else:
            print(f"{folder_name} failed to run in {base_folder}.\n")
    else:
        print(f"File {folder_name}.ino not found in {folder_name} within {base_folder}")

print("Data collection complete.")
# Out:
# Running speck128rfid_16 in speck128rfidd...
# speck128rfid_16.ino - Flash: 15104 / 30720 bytes, RAM: 1107 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83
# Encryption Completed in 460 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 472 us
# Memory Usage = 1142 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.00 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.10 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_32 in speck128rfidd...
# speck128rfid_32.ino - Flash: 15178 / 30720 bytes, RAM: 1139 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 636 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 656 us
# Memory Usage = 1174 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 6.80 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.17 V
# Decryption Current: 7.00 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_48 in speck128rfidd...
# speck128rfid_48.ino - Flash: 15192 / 30720 bytes, RAM: 1171 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 824 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 844 us
# Memory Usage = 1208 B
#
# Encryption Voltage: 4.17 V
# Encryption Current: 6.90 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.17 V
# Decryption Current: 7.10 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_64 in speck128rfidd...
# speck128rfid_64.ino - Flash: 15220 / 30720 bytes, RAM: 1203 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 996 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 1036 us
# Memory Usage = 1240 B
#
# Encryption Voltage: 4.17 V
# Encryption Current: 7.00 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.17 V
# Decryption Current: 7.10 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_80 in speck128rfidd...
# speck128rfid_80.ino - Flash: 15220 / 30720 bytes, RAM: 1235 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 1176 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 1220 us
# Memory Usage = 1272 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.30 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.17 V
# Decryption Current: 7.30 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_96 in speck128rfidd...
# speck128rfid_96.ino - Flash: 15220 / 30720 bytes, RAM: 1267 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 1352 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 1404 us
# Memory Usage = 1304 B
#
# Encryption Voltage: 4.17 V
# Encryption Current: 7.20 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.17 V
# Decryption Current: 7.00 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_112 in speck128rfidd...
# speck128rfid_112.ino - Flash: 15268 / 30720 bytes, RAM: 1299 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 1528 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 1588 us
# Memory Usage = 1336 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 6.90 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.17 V
# Decryption Current: 7.00 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_128 in speck128rfidd...
# speck128rfid_128.ino - Flash: 15294 / 30720 bytes, RAM: 1331 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 1704 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 1772 us
# Memory Usage = 1368 B
#
# Encryption Voltage: 4.17 V
# Encryption Current: 7.00 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 6.90 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_144 in speck128rfidd...
# speck128rfid_144.ino - Flash: 15292 / 30720 bytes, RAM: 1363 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 1888 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 1960 us
# Memory Usage = 1400 B
#
# Encryption Voltage: 4.17 V
# Encryption Current: 7.10 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.17 V
# Decryption Current: 7.20 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_160 in speck128rfidd...
# speck128rfid_160.ino - Flash: 15292 / 30720 bytes, RAM: 1395 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 2064 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 2156 us
# Memory Usage = 1432 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 6.90 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.17 V
# Decryption Current: 6.80 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_176 in speck128rfidd...
# speck128rfid_176.ino - Flash: 15292 / 30720 bytes, RAM: 1427 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 2240 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 2340 us
# Memory Usage = 1464 B
#
# Encryption Voltage: 4.17 V
# Encryption Current: 7.10 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.17 V
# Decryption Current: 7.00 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_192 in speck128rfidd...
# speck128rfid_192.ino - Flash: 15292 / 30720 bytes, RAM: 1459 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 2416 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 2528 us
# Memory Usage = 1496 B
#
# Encryption Voltage: 4.17 V
# Encryption Current: 7.00 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.10 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_208 in speck128rfidd...
# speck128rfid_208.ino - Flash: 15292 / 30720 bytes, RAM: 1491 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 2592 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 2712 us
# Memory Usage = 1528 B
#
# Encryption Voltage: 4.17 V
# Encryption Current: 7.10 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.10 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_224 in speck128rfidd...
# speck128rfid_224.ino - Flash: 15292 / 30720 bytes, RAM: 1523 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 2776 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 2896 us
# Memory Usage = 1560 B
#
# Encryption Voltage: 4.17 V
# Encryption Current: 7.10 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.17 V
# Decryption Current: 7.10 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_240 in speck128rfidd...
# speck128rfid_240.ino - Flash: 15292 / 30720 bytes, RAM: 1555 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 2952 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 3080 us
# Memory Usage = 1592 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.10 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.10 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_256 in speck128rfidd...
# speck128rfid_256.ino - Flash: 15290 / 30720 bytes, RAM: 1587 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 3128 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 3272 us
# Memory Usage = 1624 B
#
# Encryption Voltage: 4.17 V
# Encryption Current: 7.30 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.17 V
# Decryption Current: 7.40 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_272 in speck128rfidd...
# speck128rfid_272.ino - Flash: 15162 / 30720 bytes, RAM: 1619 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 3304 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 3432 us
# Memory Usage = -26030 B
#
# Encryption Voltage: 4.18 V
# Encryption Current: 0.00 mA
# Encryption Power: 0.00 W
#
# Decryption Voltage: 31.74 V
# Decryption Current: 0.00 mA
# Decryption Power: 0.00 W
# selesai
# Running speck128rfid_288 in speck128rfidd...
# speck128rfid_288.ino - Flash: 15162 / 30720 bytes, RAM: 1651 / 2048 bytes
# Running speck128rfid_304 in speck128rfidd...
# speck128rfid_304.ino - Flash: 15162 / 30720 bytes, RAM: 1683 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 3656 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 3800 us
# Memory Usage = -29863 B
#
# Encryption Voltage: 0.40 V
# Encryption Current: 0.00 mA
# Encryption Power: 0.00 W
#
# Decryption Voltage: 7.17 V
# Decryption Current: 0.00 mA
# Decryption Power: 0.00 W
# selesai
# Running speck128rfid_320 in speck128rfidd...
# speck128rfid_320.ino - Flash: 15162 / 30720 bytes, RAM: 1715 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 3840 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 3988 us
# Memory Usage = -195 B
#
# Encryption Voltage: 0.40 V
# Encryption Current: 0.00 mA
# Encryption Power: 0.00 W
#
# Decryption Voltage: 11.26 V
# Decryption Current: 0.00 mA
# Decryption Power: 0.00 W
# selesai
# Running speck128rfid_336 in speck128rfidd...
# speck128rfid_336.ino - Flash: 15162 / 30720 bytes, RAM: 1747 / 2048 bytes
# Ciphertext: FE 45 09 00 1A 60 1D 20 5A 14 1D 79 16 CF 07 08 8E CB 75 D4 6C 9D B8 60 81 13 FD 65 C0 CC E6 9B D9 D8 CE 21 28 E1 7E EB 02 5F 12 24 71 40 11 6E 48 96 21 6D 9E 9F 0C 4F 6D 54 8E A4 B2 4B 63 F3 12 46 94 2F 2C 94 EE 72 F5 1D 67 B8 C7 F9 FA 6B 4F 3F 3E 97 90 BA 4E 51 B6 D9 4D D6 8F 27 36 E8 8A 9E 43 48 D2 F7 67 97 9D 1E C7 D0 05 1B 39 10 D3 F0 DD 9D 22 D8 7D 29 5C 5A 1D 62 E2 F9 B8 0E 5F BE A3 D5 A5 47 84 F8 45 6C 1D 80 87 DE 6B EF 61 D6 F3 9C 38 0B 3E 2F 85 E1 8A F2 CB D9 2A A0 1C 09 B7 21 FB 60 62 8A 9B 57 DB A0 D9 B3 56 34 F6 99 19 43 03 89 28 DF F8 D9 D7 44 E6 7B FC E4 C5 DC 29 4F 91 0D F4 F5 CA C4 D4 7B ED B0 34 5B 63 7C 7A 90 CC 37 72 3A 66 15 8A D1 B1 F3 F2 A0 F1 6D 2A 30 96 E8 7F 7C 5B 15 34 56 C4 05 32 9D BD 6E 74 F0 70 33 81 61 77 62 B1 F7 6B 73 B8 8A 05 F0 92 90 38 B7 53 FD 64 2C DA 24 1C 58 FF 9C 34 81 B6 95 A1 0D E4 FB 12 3B FC D3 51 E7 98 C9 E0 13 AC 30 8C C6 4A 7E 87 0C 0C 2E 2E 42 90 23 A2 19 99 47 68 4F A4 6B 9B 0C 7D D9 05 2F 5F 13 49 E5 E4 48 FF 07 FA 32 16 DC 8D B0 B2 69 2F 3C
# Encryption Completed in 27676 us
# Decrypted Text: CE FB A2 84 62 10 DC BC 71 E0 56 E9 D9 60 78 CD 3E B7 21 B1 32 EC 27 7A 9A 6A 3D 37 26 25 51 7D 5B FE 09 6F 8B D1 D2 93 A8 A8 4A F4 D4 79 5B 94 14 96 50 86 68 89 A8 43 EA 1D BD D5 C5 F7 53 83 8A 0F E1 28 05 12 B8 13 3F 96 60 79 E3 81 E3 7C D0 0A 2F 53 E8 2B 49 D0 B3 8D 30 40 62 79 74 DC 0C EC 69 00 C2 65 66 57 88 AA F5 98 86 0E 03 E5 82 E3 84 16 40 2B FC 34 1E 38 D7 11 67 73 46 EA 55 A9 31 80 47 C1 D9 16 A5 71 B4 EA EE 2F 85 45 A4 6D D8 2D 2D 80 3C D6 0C ED D9 D9 23 A2 69 56 B1 4E 85 3B C8 60 1D F0 2A 9C B8 7A 63 D0 31 6F 59 FD D0 4A 24 A3 5E 26 4E CE 8A B0 59 0E A9 17 B0 5D 32 FA 64 B0 5C D7 95 A5 CC AE 89 3F 66 1A 2E 22 F7 C5 B8 47 55 9E 03 A1 86 AA 91 75 F4 21 6E E0 4F FA 4E DD 14 FF E3 5D BB 66 37 08 2A A6 4C 0B F4 B4 28 EF 7E 37 27 6F E0 79 C7 61 B9 14 BE E5 79 F4 E7 37 A5 20 A7 CF 4B AF 11 51 86 7E 8C BE D2 88 87 17 67 EE 13 D4 8B C6 DB 12 AF BB 6E B6 F8 86 C1 3E FB 68 5A 81 C9 33 22 F1 9E 48 EC F4 5A 65 E6 0F 15 C7 80 AD AA 41 EE FE B4 D1 BF 71 71 02 44 0A 02 E5 04 A8 15 83 34 A0 A6 D9
# Decryption Completed in 28904 us
# Memory Usage = -195 B
#
# Encryption Voltage: 0.41 V
# Encryption Current: 0.00 mA
# Encryption Power: 0.00 W
#
# Decryption Voltage: 15.36 V
# Decryption Current: 0.00 mA
# Decryption Power: 0.00 W
# selesai
# Running speck128rfid_352 in speck128rfidd...
# speck128rfid_352.ino - Flash: 15162 / 30720 bytes, RAM: 1779 / 2048 bytes
# Ciphertext: 50 95 A2 DA DA D8 FF 22 94 FC DB 6E D6 92 2C C5 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20
# Encryption Completed in 1484 us
# Decrypted Text: 2F 5C E8 B2 59 A6 12 43 AA A0 3B 18 D1 31 16 E2 68 64 C7 8C 46 FB FF 19 89 CD 8E 30 A8 CD 14 20 FC CA F3 46 FD 72 0C 84 B3 1C C8 FC 24 BF BF 46 0F 2B 16 97 CE 44 1A 1F 35 10 5D 9E AA BB 50 6E ED 54 98 EA 11 B1 DE C3 F9 54 1D 51 F3 A5 86 FD 7C 5C 0E 98 AA E1 29 F7 B1 89 D8 FA DA 04 32 86 20 2E 7B 66 6A 3D 69 27 4D 6F 83 C1 BF 80 03 D3 94 A2 3E 85 B4 BD D1 E8 E4 56 5B 83 7A 42 49 8F C8 16 58 D6 96 A3 11 C9 DE 1B 1D 70 FE 34 D7 69 50 C3 B0 13 45 9A 5F FF 4C 66 EA C1 EB 4C 12 D9 DD F0 BC 76 08 73 41 AC 8A 01 E4 1E 51 03 1E 93 A3 9F 7F 3D 8A B3 E2 CE E6 BD 38 53 70 49 C9 3E DB A1 53 30 71 60 93 10 3E BF B9 34 EB 03 0E 3F 61 90 4E 74 2D B7 2D 1B D1 48 D1 61 97 C3 EC 39 3D 08 8D 48 53 F1 EC F2 7D 3F E9 8E D7 89 BB 52 1F BD B5 07 7A 04 8B 28 D2 6E 6C BB 27 A7 D6 17 69 93 F3 E3 AA 60 F6 D6 11 14 A1 EA 99 6A BD D3 4C 84 91 67 90 02 05 50 72 99 97 4B 63 50 52 83 21 BA B4 40 56 37 F5 A9 E5 7F 8F 6B 2A B8 89 6F FA 75 A8 1D B6 CF E4 3A AA DB 14 FD 3B B8 43 7D 3C 8B D4 A3 9B 94 30 85 9D 83 EC 96 E8 F7 AE 6B 3A A4 63 74 F2 4F E4 CC 94 72 78 71 5D 07 BB EE
# Decryption Completed in 16768 us
# Memory Usage = 13117 B
#
# Encryption Voltage: 0.42 V
# Encryption Current: 0.00 mA
# Encryption Power: 0.00 W
#
# Decryption Voltage: 19.46 V
# Decryption Current: 0.00 mA
# Decryption Power: 0.00 W
# selesai
# Running speck128rfid_368 in speck128rfidd...
# speck128rfid_368.ino - Flash: 15162 / 30720 bytes, RAM: 1811 / 2048 bytes
# Running speck128rfid_384 in speck128rfidd...
# speck128rfid_384.ino - Flash: 15162 / 30720 bytes, RAM: 1843 / 2048 bytes
# Running speck128rfid_400 in speck128rfidd...
# speck128rfid_400.ino - Flash: 15162 / 30720 bytes, RAM: 1875 / 2048 bytes
# Data collection complete.

# %%
# e

import os
import re
import subprocess
import time
import serial

# Configurations
port = "COM18"
baud_rate = 9600
base_folder = "speck128rfide"  # Hanya folder yang diinginkan
arduino_cli_path = r"C:\Program Files\Arduino IDE\resources\app\lib\backend\resources\arduino-cli.exe"
log_base_folder = "../../logs"

# Ensure the base log folder exists
os.makedirs(log_base_folder, exist_ok=True)

def compile_and_upload(sketch_path, log_file):
    # Compile and upload code to Arduino
    compile_command = [arduino_cli_path, "compile", "--fqbn", "arduino:avr:nano", sketch_path]
    upload_command = [arduino_cli_path, "upload", "-p", port, "--fqbn", "arduino:avr:nano", sketch_path]

    # Run compile command and capture output for memory usage
    compile_result = subprocess.run(compile_command, capture_output=True, text=True)
    upload_result = subprocess.run(upload_command, capture_output=True, text=True)
    time.sleep(2)  # Wait for Arduino to reset

    # Extract flash and RAM usage from the compile output
    flash_usage = ram_usage = None
    flash_match = re.search(r"Sketch uses (\d+) bytes.*Maximum is (\d+) bytes", compile_result.stdout)
    ram_match = re.search(r"Global variables use (\d+) bytes.*Maximum is (\d+) bytes", compile_result.stdout)
    if flash_match and ram_match:
        flash_usage = f"{flash_match.group(1)} / {flash_match.group(2)} bytes"
        ram_usage = f"{ram_match.group(1)} / {ram_match.group(2)} bytes"
        print(f"{os.path.basename(sketch_path)} - Flash: {flash_usage}, RAM: {ram_usage}")
    else:
        print(f"{os.path.basename(sketch_path)} - Failed to retrieve memory usage information")

    # Write Flash and RAM info to the log file
    with open(log_file, "w") as f:
        if flash_usage and ram_usage:
            f.write(f"Flash Usage: {flash_usage}, RAM Usage: {ram_usage}\n\n")
        else:
            f.write("Failed to retrieve memory usage information\n\n")

    # Return success or failure based on the result of compile and upload
    return compile_result.returncode == 0 and upload_result.returncode == 0

def record_serial_data(log_file):
    # Capture serial output to a log file
    with serial.Serial(port, baud_rate, timeout=1) as ser, open(log_file, 'a') as file:  # Open in append mode
        ser.flushInput()  # Clear any leftover data in the buffer
        start_time = time.time()
        while time.time() - start_time < 10:  # 10-second timeout
            if ser.in_waiting > 0:
                line = ser.readline().decode('utf-8').strip()
                file.write(line + '\n')
                print(line)
                if 'selesai' in line.lower():
                    break
        time.sleep(1)  # Additional wait to ensure all data is captured

# Define log folder for the current base folder
log_folder = os.path.join(log_base_folder, f"logs_{base_folder}")
os.makedirs(log_folder, exist_ok=True)  # Create folder if it doesn't exist

# Get sorted list of subfolders in the base folder
subfolders = sorted(
    [folder for folder in os.listdir(base_folder) if os.path.isdir(os.path.join(base_folder, folder))],
    key=lambda x: int(x.split('_')[1])
)

for folder_name in subfolders:
    sketch_path = os.path.join(base_folder, folder_name, f"{folder_name}.ino")
    if os.path.isfile(sketch_path):
        print(f"Running {folder_name} in {base_folder}...")

        # Define log file path for the current sketch
        log_file = os.path.join(log_folder, f"{folder_name}.txt")

        # Compile and upload; skip if failed
        if compile_and_upload(sketch_path, log_file):
            # Capture serial output
            record_serial_data(log_file)
        else:
            print(f"{folder_name} failed to run in {base_folder}.\n")
    else:
        print(f"File {folder_name}.ino not found in {folder_name} within {base_folder}")

print("Data collection complete.")
# Out:
# Running speck128rfid_16 in speck128rfide...
# speck128rfid_16.ino - Flash: 15104 / 30720 bytes, RAM: 1107 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83
# Encryption Completed in 460 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 472 us
# Memory Usage = 1142 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.00 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.10 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_32 in speck128rfide...
# speck128rfid_32.ino - Flash: 15178 / 30720 bytes, RAM: 1139 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 636 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 656 us
# Memory Usage = 1174 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.10 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.10 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_48 in speck128rfide...
# speck128rfid_48.ino - Flash: 15192 / 30720 bytes, RAM: 1171 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 824 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 844 us
# Memory Usage = 1208 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.20 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.10 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_64 in speck128rfide...
# speck128rfid_64.ino - Flash: 15220 / 30720 bytes, RAM: 1203 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 996 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 1036 us
# Memory Usage = 1240 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.00 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 6.80 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_80 in speck128rfide...
# speck128rfid_80.ino - Flash: 15220 / 30720 bytes, RAM: 1235 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 1176 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 1220 us
# Memory Usage = 1272 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.20 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 6.90 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_96 in speck128rfide...
# speck128rfid_96.ino - Flash: 15220 / 30720 bytes, RAM: 1267 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 1352 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 1404 us
# Memory Usage = 1304 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 6.90 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 6.80 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_112 in speck128rfide...
# speck128rfid_112.ino - Flash: 15268 / 30720 bytes, RAM: 1299 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 1528 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 1588 us
# Memory Usage = 1336 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.00 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.00 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_128 in speck128rfide...
# speck128rfid_128.ino - Flash: 15294 / 30720 bytes, RAM: 1331 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 1704 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 1772 us
# Memory Usage = 1368 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 6.90 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.00 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_144 in speck128rfide...
# speck128rfid_144.ino - Flash: 15292 / 30720 bytes, RAM: 1363 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 1888 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 1960 us
# Memory Usage = 1400 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.00 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.00 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_160 in speck128rfide...
# speck128rfid_160.ino - Flash: 15292 / 30720 bytes, RAM: 1395 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 2064 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 2156 us
# Memory Usage = 1432 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.10 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.15 V
# Decryption Current: 7.10 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_176 in speck128rfide...
# speck128rfid_176.ino - Flash: 15292 / 30720 bytes, RAM: 1427 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 2240 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 2340 us
# Memory Usage = 1464 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.00 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 6.90 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_192 in speck128rfide...
# speck128rfid_192.ino - Flash: 15292 / 30720 bytes, RAM: 1459 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 2416 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 2528 us
# Memory Usage = 1496 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.00 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.00 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_208 in speck128rfide...
# speck128rfid_208.ino - Flash: 15292 / 30720 bytes, RAM: 1491 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 2592 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 2712 us
# Memory Usage = 1528 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.00 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 6.80 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_224 in speck128rfide...
# speck128rfid_224.ino - Flash: 15292 / 30720 bytes, RAM: 1523 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 2776 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 2896 us
# Memory Usage = 1560 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 6.80 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 7.00 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_240 in speck128rfide...
# speck128rfid_240.ino - Flash: 15292 / 30720 bytes, RAM: 1555 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 2952 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 3080 us
# Memory Usage = 1592 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.10 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.16 V
# Decryption Current: 6.90 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_256 in speck128rfide...
# speck128rfid_256.ino - Flash: 15290 / 30720 bytes, RAM: 1587 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 3128 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 3272 us
# Memory Usage = 1624 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 7.00 mA
# Encryption Power: 0.03 W
#
# Decryption Voltage: 4.15 V
# Decryption Current: 7.00 mA
# Decryption Power: 0.03 W
# selesai
# Running speck128rfid_272 in speck128rfide...
# speck128rfid_272.ino - Flash: 15162 / 30720 bytes, RAM: 1619 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 3304 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 3428 us
# Memory Usage = -26030 B
#
# Encryption Voltage: 4.16 V
# Encryption Current: 0.00 mA
# Encryption Power: 0.00 W
#
# Decryption Voltage: 31.74 V
# Decryption Current: 0.00 mA
# Decryption Power: 0.00 W
# selesai
# Running speck128rfid_288 in speck128rfide...
# speck128rfid_288.ino - Flash: 15162 / 30720 bytes, RAM: 1651 / 2048 bytes
# Running speck128rfid_304 in speck128rfide...
# speck128rfid_304.ino - Flash: 15162 / 30720 bytes, RAM: 1683 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 3656 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 3800 us
# Memory Usage = -29863 B
#
# Encryption Voltage: 0.40 V
# Encryption Current: 0.00 mA
# Encryption Power: 0.00 W
#
# Decryption Voltage: 7.17 V
# Decryption Current: 0.00 mA
# Decryption Power: 0.00 W
# selesai
# Running speck128rfid_320 in speck128rfide...
# speck128rfid_320.ino - Flash: 15162 / 30720 bytes, RAM: 1715 / 2048 bytes
# Ciphertext: 89 51 BC 94 2A A2 70 D5 3F C7 D2 88 59 E8 A9 83 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39 70 22 1A 53 4E 04 7E 53 3F 3A 24 89 94 A3 95 39
# Encryption Completed in 3840 us
# Decrypted Text: 23 EE AE 0D 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00
# Decryption Completed in 3984 us
# Memory Usage = -195 B
#
# Encryption Voltage: 0.40 V
# Encryption Current: 0.00 mA
# Encryption Power: 0.00 W
#
# Decryption Voltage: 11.26 V
# Decryption Current: 0.00 mA
# Decryption Power: 0.00 W
# selesai
# Running speck128rfid_336 in speck128rfide...
# speck128rfid_336.ino - Flash: 15162 / 30720 bytes, RAM: 1747 / 2048 bytes
# Ciphertext: F7 0C B2 77 A4 3B 82 CF 06 65 46 22 53 20 D3 8F B9 AB A0 7C EA E7 9F AA 42 9D 86 9F BE 4C 58 A8 17 FF C0 A8 A4 09 5D FA 1C BC 6C BD 10 86 1C C2 E6 93 26 A5 D1 6D 98 40 11 FA EE 99 B0 2A 2D 79 CD 9B CF C8 CC 55 AF E1 64 E6 C4 65 C9 38 92 50 87 EA 57 C0 34 89 A8 80 73 76 C3 5E 3F 25 63 C3 F1 5E 55 CD 04 27 10 72 65 AC 4F 09 A1 C7 8D FE 5C 85 0C CA 29 03 94 6E CA 3E D4 71 2F 69 FB E8 C8 F5 DA DE 27 5C DA E1 C0 BA F3 40 24 44 8B 8E 4F 55 FF 9D 7B 42 59 18 AB F9 85 3A 79 D2 7B 01 23 98 F1 96 1C AB EB 09 70 58 24 42 A6 C0 85 55 38 EB 20 C6 4A E9 63 36 EC 0A B2 7B A9 DE 36 90 A3 05 19 3F 90 FC 52 34 50 67 28 DD AE 2F B1 92 C0 52 33 5C 2C 0F BC DE A6 11 D8 8C C6 47 1F 60 49 2F D5 EC A8 17 34 EC 44 C2 6F 4F FF 21 01 CE FB 00 06 08 64 EA AB 6B 4E 21 D8 73 95 B0 62 A5 C4 12 02 88 6F A8 6C 80 D4 B3 47 6E DA 2E EB 07 88 BE 84 2D CA 15 D9 A4 AC 79 CF 80 93 51 61 8F 22 A5 B9 96 72 48 FE 51 11 59 CD D8 FD 53 AF B1 72 69 2F 87 C5 E0 42 16 E4 59 58 0D 55 3F 85 A9 4D 77 48 09 8E 6F 0A BF B9 5F 23 2B 89 CB F0 51
# Encryption Completed in 27676 us
# Decrypted Text: 5E BE A7 D8 CC 94 6F C5 D7 15 C9 E5 2A DC 95 71 7C 47 B2 D0 46 F3 B1 EB 42 C2 11 2C 0A 4C A9 0B C8 E1 7A 8F C9 0D A1 7E 19 D1 85 55 5E 3D 5D 49 08 29 58 5F 4C CD C0 C1 A8 56 7E E3 28 86 5A AD A9 C0 AF AC 27 97 23 17 F1 0C 29 70 49 08 37 A0 76 F7 C1 99 DC F5 E9 51 3A F3 8E 1B 3F F7 9C 1C DA 90 30 19 BD 9C A6 94 9F 56 E4 38 16 8D 66 55 C2 BB B0 FB 02 A1 E5 FD 99 71 EA 52 F3 19 77 C8 2C CB 1D 27 25 C4 45 BF 05 33 08 79 8D 40 4A DE 31 9B 72 1A 75 CE 3C 14 9D 45 8E 03 5F 15 04 C9 94 A8 B5 73 19 38 0E 6F A0 39 59 54 07 AA DE 47 92 03 CA 6D 9D ED 00 CD F1 A2 51 4B E9 3A 97 1B A9 63 A1 FD 31 F4 45 17 C8 12 E1 14 D3 46 FD 99 D6 11 6C 53 A4 B1 A9 71 11 4D 3F D8 CC 40 CF 18 C4 C7 00 6B F2 6F 4A 74 36 4B 7C 6A DA 4F EC 24 88 55 23 05 D0 01 47 B1 27 30 16 AF B5 BA 8C 44 2B FB 6E 27 C5 FB DD 4B 33 9C 44 07 56 A7 B5 36 D8 61 3D 4E 3D 01 DA 5C 2B 31 12 CD 0A B9 6F FD BA D9 8A 8E DD 13 9E E1 CA 3F 5B DB EB 97 E0 D6 40 69 1A 2D AE FC 16 EF 42 CD 3C B4 56 ED DA 25 E2 7C 27 35 C4 A9 B0 3E E4 2F ED 3D E9 1F 65 44
# Decryption Completed in 28912 us
# Memory Usage = -195 B
#
# Encryption Voltage: 0.41 V
# Encryption Current: 0.00 mA
# Encryption Power: 0.00 W
#
# Decryption Voltage: 15.36 V
# Decryption Current: 0.00 mA
# Decryption Power: 0.00 W
# selesai
# Running speck128rfid_352 in speck128rfide...
# speck128rfid_352.ino - Flash: 15162 / 30720 bytes, RAM: 1779 / 2048 bytes
# Ciphertext: 50 95 A2 DA DA D8 FF 22 94 FC DB 6E D6 92 2C C5 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 E4 A5 5D 4E B7 6C 86 B4 6F BA 03 F5 AD 77 57 62 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20 62 28 46 53 A4 69 9F 33 1F F8 59 FE CF D3 24 20
# Encryption Completed in 1484 us
# Decrypted Text: 87 74 E9 E5 EC E5 A0 71 64 58 CB A6 DB 05 F5 7C B2 35 4C 48 C0 08 21 BB 53 56 C8 42 9A B1 72 DA D4 05 D7 A1 E1 8A C6 43 06 AC 18 78 CB 2A B7 CE F4 DC 09 50 3B CA A7 9B 47 48 B6 56 0E 30 3A CC ED 54 98 EA 11 B1 DE C3 F9 54 1D 51 F3 A5 86 FD 7C 5C 0E 98 AA E1 29 F7 B1 89 D8 FA DA 04 32 86 6B F7 7E DB 8B 6C 02 CA 72 CA 89 9D 5F E8 16 73 FF F9 CF F5 DC CD D0 1A A4 DD D5 2E 80 A9 A7 18 DA 09 70 3C 5E AB DA 2D B4 15 D3 C4 8E D9 F4 5C 28 B9 AB 22 D2 F1 CE D5 94 1D 79 22 A5 44 FE 62 9C 45 CB 40 02 BB 05 2A 2E 6F EB 83 C1 A3 13 BC 7B 49 A9 E4 4E 12 2E 05 32 A4 5F A8 8A FB 03 00 6D 2F 9C C0 E7 95 10 BF DF 52 A2 88 10 36 8D B6 CA 8F BB 58 DC E6 DA EC FE BE 85 5A E5 5B 4C 3C 05 F2 9F C0 B4 7F 64 DE 72 00 3B B3 46 46 35 7F 73 10 F4 22 50 2A C8 E6 E4 F5 41 05 5E B3 15 98 8E CA 22 B9 E3 46 8C D2 A4 00 DE 5B 5C 15 D7 6F 28 05 B3 5A C0 89 6F 0B F2 A9 28 BB E9 B7 98 87 76 21 1F 86 0A D3 73 5B F1 C4 F7 90 F3 D7 E6 84 88 AB 5F D9 4A 57 4E C9 47 D1 04 C4 34 09 76 4E 3C 8B D4 A3 9B 94 30 85 9D 83 EC 96 E8 F7 AE 6B 3A A4 63 74 F2 4F E4 CC 94 72 78 71 5D 07 BB EE
# Decryption Completed in 16768 us
# Memory Usage = 13117 B
#
# Encryption Voltage: 0.42 V
# Encryption Current: 0.00 mA
# Encryption Power: 0.00 W
#
# Decryption Voltage: 19.46 V
# Decryption Current: 0.00 mA
# Decryption Power: 0.00 W
# selesai
# Running speck128rfid_368 in speck128rfide...
# speck128rfid_368.ino - Flash: 15162 / 30720 bytes, RAM: 1811 / 2048 bytes
# Running speck128rfid_384 in speck128rfide...
# speck128rfid_384.ino - Flash: 15162 / 30720 bytes, RAM: 1843 / 2048 bytes
# Running speck128rfid_400 in speck128rfide...
# speck128rfid_400.ino - Flash: 15162 / 30720 bytes, RAM: 1875 / 2048 bytes
# Data collection complete.

# %%
import os
import re
import csv

# Define the main directory paths
log_base_folder = "../../logs"
output_base_folder = "../../Data_CSV_128/CSVs_128"

# Ensure the output folder exists
os.makedirs(output_base_folder, exist_ok=True)

# Define the header for the CSV files
header = [
    "file_name", "flash_usage", "ram_usage", "memory_usage",
    "encryption_time", "encryption_voltage", "encryption_current", "encryption_power",
    "decryption_time", "decryption_voltage", "decryption_current", "decryption_power"
]

# Function to parse individual .txt files
def parse_txt_file(file_path):
    with open(file_path, 'r') as f:
        data = f.read()

    # Extract flash usage and RAM usage, capturing only the number before "/"
    flash_match = re.search(r"Flash Usage: (\d+) / \d+ bytes", data)
    ram_match = re.search(r"RAM Usage: (\d+) / \d+ bytes", data)
    memory_match = re.search(r"Memory Usage = (\d+) B", data)

    # Extract encryption and decryption times
    encryption_time_match = re.search(r"Encryption Completed in (\d+) us", data)
    decryption_time_match = re.search(r"Decryption Completed in (\d+) us", data)

    # Extract encryption and decryption voltages and currents
    encryption_voltage_match = re.search(r"Encryption Voltage: ([\d.]+) V", data)
    encryption_current_match = re.search(r"Encryption Current: ([\d.]+) mA", data)
    decryption_voltage_match = re.search(r"Decryption Voltage: ([\d.]+) V", data)
    decryption_current_match = re.search(r"Decryption Current: ([\d.]+) mA", data)

    # Extract values if matches are found, else set as None
    flash_usage = int(flash_match.group(1)) if flash_match else None
    ram_usage = int(ram_match.group(1)) if ram_match else None
    memory_usage = int(memory_match.group(1)) if memory_match else None
    encryption_time = int(encryption_time_match.group(1)) if encryption_time_match else None
    decryption_time = int(decryption_time_match.group(1)) if decryption_time_match else None
    encryption_voltage = float(encryption_voltage_match.group(1)) if encryption_voltage_match else None
    encryption_current = float(encryption_current_match.group(1)) if encryption_current_match else None
    decryption_voltage = float(decryption_voltage_match.group(1)) if decryption_voltage_match else None
    decryption_current = float(decryption_current_match.group(1)) if decryption_current_match else None

    # Calculate encryption and decryption power
    encryption_power = encryption_voltage * (encryption_current / 1000) if encryption_voltage and encryption_current else None
    decryption_power = decryption_voltage * (decryption_current / 1000) if decryption_voltage and decryption_current else None

    # Return all extracted data as a dictionary
    return {
        "file_name": os.path.splitext(os.path.basename(file_path))[0],  # Remove ".txt" from file name
        "flash_usage": flash_usage,
        "ram_usage": ram_usage,
        "memory_usage": memory_usage,
        "encryption_time": encryption_time,
        "encryption_voltage": encryption_voltage,
        "encryption_current": encryption_current,
        "encryption_power": encryption_power,
        "decryption_time": decryption_time,
        "decryption_voltage": decryption_voltage,
        "decryption_current": decryption_current,
        "decryption_power": decryption_power
    }

# Loop through each log folder
for log_folder in os.listdir(log_base_folder):
    log_folder_path = os.path.join(log_base_folder, log_folder)
    if os.path.isdir(log_folder_path) and log_folder.startswith("logs_speck128rfid"):
        # Define output CSV file path for each folder
        output_csv = os.path.join(output_base_folder, f"{log_folder}.csv")

        # List to hold all parsed data for this folder
        all_data = []

        # Retrieve and sort .txt files numerically based on the number after "aes128rfid_"
        txt_files = sorted(
            [file for file in os.listdir(log_folder_path) if file.endswith(".txt")],
            key=lambda x: int(re.search(r'speck128rfid_(\d+)', x).group(1))  # Extract the number after "aes128rfid_" and sort numerically
        )

        # Process each sorted .txt file
        for file_name in txt_files:
            file_path = os.path.join(log_folder_path, file_name)
            file_data = parse_txt_file(file_path)
            all_data.append(file_data)

        # Write all sorted data to CSV
        with open(output_csv, 'w', newline='') as csv_file:
            writer = csv.DictWriter(csv_file, fieldnames=header)
            writer.writeheader()
            writer.writerows(all_data)

        print(f"Data from {log_folder} has been successfully saved to {output_csv} in the correct order.")
# Out:
# Data from logs_speck128rfida has been successfully saved to ../../Data_CSV_128/CSVs_128\logs_speck128rfida.csv in the correct order.
# Data from logs_speck128rfidb has been successfully saved to ../../Data_CSV_128/CSVs_128\logs_speck128rfidb.csv in the correct order.
# Data from logs_speck128rfidc has been successfully saved to ../../Data_CSV_128/CSVs_128\logs_speck128rfidc.csv in the correct order.
# Data from logs_speck128rfidd has been successfully saved to ../../Data_CSV_128/CSVs_128\logs_speck128rfidd.csv in the correct order.
# Data from logs_speck128rfide has been successfully saved to ../../Data_CSV_128/CSVs_128\logs_speck128rfide.csv in the correct order.

# %%
import os
import re
import csv

# Define the main directory paths
log_base_folder = "../../logs"
output_base_folder = "../../Data_CSV_128/CSVs_128_chippertext"

# Ensure the output folder exists
os.makedirs(output_base_folder, exist_ok=True)

# Define the header for the CSV files
header = [
    "file_name", "ciphertext", "decrypted_text"
]

# Function to parse individual .txt files
def parse_txt_file(file_path):
    with open(file_path, 'r') as f:
        data = f.read()

    # Extract ciphertext and decrypted text
    ciphertext_match = re.search(r"Ciphertext: ([0-9A-Fa-f ]+)", data)
    decrypted_text_match = re.search(r"Decrypted Text: ([0-9A-Fa-f ]+)", data)

    # Extract values if matches are found, else set as None
    ciphertext = ciphertext_match.group(1).strip() if ciphertext_match else None
    decrypted_text = decrypted_text_match.group(1).strip() if decrypted_text_match else None

    # Return all extracted data as a dictionary
    return {
        "file_name": os.path.splitext(os.path.basename(file_path))[0],  # Remove ".txt" from file name
        "ciphertext": ciphertext,
        "decrypted_text": decrypted_text
    }

# Loop through each log folder
for log_folder in os.listdir(log_base_folder):
    log_folder_path = os.path.join(log_base_folder, log_folder)
    if os.path.isdir(log_folder_path) and log_folder.startswith("logs_speck128rfid"):
        # Define output CSV file path for each folder
        output_csv = os.path.join(output_base_folder, f"{log_folder}.csv")

        # List to hold all parsed data for this folder
        all_data = []

        # Retrieve and sort .txt files numerically based on the number after "speck128rfid_"
        txt_files = sorted(
            [file for file in os.listdir(log_folder_path) if file.endswith(".txt")],
            key=lambda x: int(re.search(r'speck128rfid_(\d+)', x).group(1))  # Extract the number after "speck128rfid_" and sort numerically
        )

        # Process each sorted .txt file
        for file_name in txt_files:
            file_path = os.path.join(log_folder_path, file_name)
            file_data = parse_txt_file(file_path)
            all_data.append(file_data)

        # Write all sorted data to CSV
        with open(output_csv, 'w', newline='') as csv_file:
            writer = csv.DictWriter(csv_file, fieldnames=header)
            writer.writeheader()
            writer.writerows(all_data)

        print(f"Data from {log_folder} has been successfully saved to {output_csv} in the correct order.")
# Out:
# Data from logs_speck128rfida has been successfully saved to ../../Data_CSV_128/CSVs_128_chippertext\logs_speck128rfida.csv in the correct order.
# Data from logs_speck128rfidb has been successfully saved to ../../Data_CSV_128/CSVs_128_chippertext\logs_speck128rfidb.csv in the correct order.
# Data from logs_speck128rfidc has been successfully saved to ../../Data_CSV_128/CSVs_128_chippertext\logs_speck128rfidc.csv in the correct order.
# Data from logs_speck128rfidd has been successfully saved to ../../Data_CSV_128/CSVs_128_chippertext\logs_speck128rfidd.csv in the correct order.
# Data from logs_speck128rfide has been successfully saved to ../../Data_CSV_128/CSVs_128_chippertext\logs_speck128rfide.csv in the correct order.

# %%
import pandas as pd
import glob
import os
import re

# Tentukan direktori yang berisi file CSV
directory = "../../Data_CSV_128/CSVs_128"

# Tentukan output path untuk menyimpan hasil rata-rata
output_path = "../../Data_CSV_128/avg_csv_128/avg_csv_128.csv"
os.makedirs(os.path.dirname(output_path), exist_ok=True)

# Temukan semua file CSV di dalam folder
file_paths = glob.glob(os.path.join(directory, '*.csv'))

# Periksa apakah ada file CSV yang ditemukan
if not file_paths:
    print("No CSV files found in the specified directory.")
else:
    # Baca semua file CSV dan simpan dalam daftar DataFrame
    dfs = [pd.read_csv(file) for file in file_paths]
    
    # Gunakan file pertama sebagai dasar untuk struktur output
    average_df = dfs[0].copy()

    # Hitung rata-rata untuk setiap kolom numerik di semua file
    for col in average_df.select_dtypes(include='number').columns:
        average_df[col] = sum(df[col] for df in dfs) / len(dfs)

    # Sort file_name secara numerik berdasarkan angka di dalam nama
    average_df['sort_key'] = average_df['file_name'].str.extract(r'(\d+)').astype(int)
    sorted_df = average_df.sort_values('sort_key').drop(columns=['sort_key']).reset_index(drop=True)
    
    # Simpan hasil rata-rata ke file CSV baru
    sorted_df.to_csv(output_path, index=False)
    print(f"Averaged and sorted CSV file saved to: {output_path}")
# Out:
# Averaged and sorted CSV file saved to: ../../Data_CSV_128/avg_csv_128/avg_csv_128.csv
